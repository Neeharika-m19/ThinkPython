# %% [markdown]
# You can order print and ebook versions of *Think Python 3e* from
# [Bookshop.org](https://bookshop.org/a/98697/9781098155438) and
# [Amazon](https://www.amazon.com/_/dp/1098155432?smid=ATVPDKIKX0DER&_encoding=UTF8&tag=oreilly20-20&_encoding=UTF8&tag=greenteapre01-20&linkCode=ur2&linkId=e2a529f94920295d27ec8a06e757dc7c&camp=1789&creative=9325).

# %%
from os.path import basename, exists

def download(url):
    filename = basename(url)
    if not exists(filename):
        from urllib.request import urlretrieve

        local, _ = urlretrieve(url, filename)
        print("Downloaded " + str(local))
    return filename

download('https://github.com/AllenDowney/ThinkPython/raw/v3/thinkpython.py');
download('https://github.com/AllenDowney/ThinkPython/raw/v3/diagram.py');

import thinkpython

# %% [markdown]
# # Text Analysis and Generation
#
# At this point we have covered Python's core data structures -- lists, dictionaries, and tuples -- and some algorithms that use them.
# In this chapter, we'll use them to explore text analysis and Markov generation:
#
# * Text analysis is a way to describe the statistical relationships between the words in a document, like the probability that one word is followed by another, and
#
# * Markov generation is a way to generate new text with words and phrases similar to the original text.
#
# These algorithms are similar to parts of a Large Language Model (LLM), which is the key component of a chatbot.
#
# We'll start by counting the number of times each word appears in a book.
# Then we'll look at pairs of words, and make a list of the words that can follow each word.
# We'll make a simple version of a Markov generator, and as an exercise, you'll have a chance to make a more general version.

# %% [markdown]
# ## Unique words
#
# As a first step toward text analysis, let's read a book -- *The Strange Case Of Dr. Jekyll And Mr. Hyde* by Robert Louis Stevenson -- and count the number of unique words.
# Instructions for downloading the book are in the notebook for this chapter.

# %% [markdown]
# The following cell downloads the book from Project Gutenberg.

# %%
# !wget 'https://www.gutenberg.org/cache/epub/43/pg43.txt'
# Out:
# --2025-05-22 04:37:51--  https://www.gutenberg.org/cache/epub/43/pg43.txt
# Resolving www.gutenberg.org (www.gutenberg.org)... 152.19.134.47, 2610:28:3090:3000:0:bad:cafe:47
# Connecting to www.gutenberg.org (www.gutenberg.org)|152.19.134.47|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 163530 (160K) [text/plain]
# Saving to: ‘pg43.txt’
#
# pg43.txt            100%[===================>] 159.70K  --.-KB/s    in 0.08s
#
# 2025-05-22 04:37:52 (2.04 MB/s) - ‘pg43.txt’ saved [163530/163530]

# %%
from google.colab import files
files.download('pg43.txt')

# %% [markdown]
# The version available from Project Gutenberg includes information about the book at the beginning and license information at the end.
# We'll use `clean_file` from Chapter 8 to remove this material and write a "clean" file that contains only the text of the book.

# %%
def is_special_line(line):
    return line.strip().startswith('*** ')

# %%
def clean_file(input_file, output_file):
    reader = open(input_file, encoding='utf-8')
    writer = open(output_file, 'w')

    for line in reader:
        if is_special_line(line):
            break

    for line in reader:
        if is_special_line(line):
            break
        writer.write(line)

    reader.close()
    writer.close()

# %%
filename = 'dr_jekyll.txt'

# %%
clean_file('pg43.txt', filename)

# %% [markdown]
# We'll use a `for` loop to read lines from the file and `split` to divide the lines into words.
# Then, to keep track of unique words, we'll store each word as a key in a dictionary.

# %%
unique_words = {}
for line in open(filename):
    seq = line.split()
    for word in seq:
        unique_words[word] = 1

len(unique_words)
# Out:
# 6042

# %% [markdown]
# The length of the dictionary is the number of unique words -- about `6000` by this way of counting.
# But if we inspect them, we'll see that some are not valid words.
#
# For example, let's look at the longest words in `unique_words`.
# We can use `sorted` to sort the words, passing the `len` function as a keyword argument so the words are sorted by length.

# %%
sorted(unique_words, key=len)[-5:]
# Out:
# ['chocolate-coloured',
#  'superiors—behold!”',
#  'coolness—frightened',
#  'gentleman—something',
#  'pocket-handkerchief.']

# %% [markdown]
# The slice index, `[-5:]`, selects the last `5` elements of the sorted list, which are the longest words.
#
# The list includes some legitimately long words, like "circumscription", and some hyphenated words, like "chocolate-coloured".
# But some of the longest "words" are actually two words separated by a dash.
# And other words include punctuation like periods, exclamation points, and quotation marks.
#
# So, before we move on, let's deal with dashes and other punctuation.

# %% [markdown]
# ## Punctuation
#
# To identify the words in the text, we need to deal with two issues:
#
# * When a dash appears in a line, we should replace it with a space -- then when we use `split`, the words will be separated.
#
# * After splitting the words, we can use `strip` to remove punctuation.
#
# To handle the first issue, we can use the following function, which takes a string, replaces dashes with spaces, splits the string, and returns the resulting list.

# %%
def split_line(line):
    return line.replace('—', ' ').split()

# %% [markdown]
# Notice that `split_line` only replaces dashes, not hyphens.
# Here's an example.

# %%
split_line('coolness—frightened')
# Out:
# ['coolness', 'frightened']

# %% [markdown]
# Now, to remove punctuation from the beginning and end of each word, we can use `strip`, but we need a list of characters that are considered punctuation.
#
# Characters in Python strings are in Unicode, which is an international standard used to represent letters in nearly every alphabet, numbers, symbols, punctuation marks, and more.
# The `unicodedata` module provides a `category` function we can use to tell which characters are punctuation.
# Given a letter, it returns a string with information about what category the letter is in.

# %%
import unicodedata

unicodedata.category('A')
# Out:
# 'Lu'

# %% [markdown]
# The category string of `'A'` is `'Lu'` -- the `'L'` means it is a letter and the `'u'` means it is uppercase.
#
# The category string of `'.'` is `'Po'` -- the `'P'` means it is punctuation and the `'o'` means its subcategory is "other".

# %%
unicodedata.category('.')
# Out:
# 'Po'

# %% [markdown]
# We can find the punctuation marks in the book by checking for characters with categories that begin with `'P'`.
# The following loop stores the unique punctuation marks in a dictionary.

# %%
punc_marks = {}
for line in open(filename):
    for char in line:
        category = unicodedata.category(char)
        if category.startswith('P'):
            punc_marks[char] = 1

# %% [markdown]
# To make a list of punctuation marks, we can join the keys of the dictionary into a string.

# %%
punctuation = ''.join(punc_marks)
print(punctuation)
# Out:
# .’;,-“”:?—‘!()_

# %% [markdown]
# Now that we know which characters in the book are punctuation, we can write a function that takes a word, strips punctuation from the beginning and end, and converts it to lower case.

# %%
def clean_word(word):
    return word.strip(punctuation).lower()

# %% [markdown]
# Here's an example.

# %%
clean_word('“Behold!”')
# Out:
# 'behold'

# %% [markdown]
# Because `strip` removes characters from the beginning and end, it leaves hyphenated words alone.

# %%
clean_word('pocket-handkerchief')
# Out:
# 'pocket-handkerchief'

# %% [markdown]
# Now here's a loop that uses `split_line` and `clean_word` to identify the unique words in the book.

# %%
unique_words2 = {}
for line in open(filename):
    for word in split_line(line):
        word = clean_word(word)
        unique_words2[word] = 1

len(unique_words2)
# Out:
# 4005

# %% [markdown]
# With this stricter definition of what a word is, there are about 4000 unique words.
# And we can confirm that the list of longest words has been cleaned up.

# %%
sorted(unique_words2, key=len)[-5:]
# Out:
# ['circumscription',
#  'unimpressionable',
#  'fellow-creatures',
#  'chocolate-coloured',
#  'pocket-handkerchief']

# %% [markdown]
# Now let's see how many times each word is used.

# %% [markdown]
# ## Word frequencies
#
# The following loop computes the frequency of each unique word.

# %%
word_counter = {}
for line in open(filename):
    for word in split_line(line):
        word = clean_word(word)
        if word not in word_counter:
            word_counter[word] = 1
        else:
            word_counter[word] += 1

# %% [markdown]
# The first time we see a word, we initialize its frequency to `1`. If we see the same word again later, we increment its frequency.
#
# To see which words appear most often, we can use `items` to get the key-value pairs from `word_counter`, and sort them by the second element of the pair, which is the frequency.
# First we'll define a function that selects the second element.

# %%
def second_element(t):
    return t[1]

# %% [markdown]
# Now we can use `sorted` with two keyword arguments:
#
# * `key=second_element` means the items will be sorted according to the frequencies of the words.
#
# * `reverse=True` means they items will be sorted in reverse order, with the most frequent words first.

# %%
items = sorted(word_counter.items(), key=second_element, reverse=True)

# %% [markdown]
# Here are the five most frequent words.

# %%
for word, freq in items[:5]:
    print(freq, word, sep='\t')
# Out:
# 1614	the
# 972	and
# 941	of
# 640	to
# 640	i

# %% [markdown]
# In the next section, we'll encapsulate this loop in a function.
# And we'll use it to demonstrate a new feature -- optional parameters.

# %% [markdown]
# ## Optional parameters
#
# We've used built-in functions that take optional parameters.
# For example, `round` takes an optional parameters called `ndigits` that indicates how many decimal places to keep.

# %%
round(3.141592653589793, ndigits=3)
# Out:
# 3.142

# %% [markdown]
# But it's not just built-in functions -- we can write functions with optional parameters, too.
# For example, the following function takes two parameters, `word_counter` and `num`.

# %%
def print_most_common(word_counter, num=5):
    items = sorted(word_counter.items(), key=second_element, reverse=True)

    for word, freq in items[:num]:
        print(freq, word, sep='\t')

# %% [markdown]
# The second parameter looks like an assignment statement, but it's not -- it's an optional parameter.
#
# If you call this function with one argument, `num` gets the **default value**, which is `5`.

# %%
print_most_common(word_counter)
# Out:
# 1614	the
# 972	and
# 941	of
# 640	to
# 640	i

# %% [markdown]
# If you call this function with two arguments, the second argument gets assigned to `num` instead of the default value.

# %%
print_most_common(word_counter, 3)
# Out:
# 1614	the
# 972	and
# 941	of

# %% [markdown]
# In that case, we would say the optional argument **overrides** the default value.
#
# If a function has both required and optional parameters, all of the required parameters have to come first, followed by the optional ones.

# %%
# %%expect SyntaxError
#
# def bad_function(n=5, word_counter):
#     return None

# %% [markdown]
# ## Dictionary subtraction
#
# Suppose we want to spell-check a book -- that is, find a list of words that might be misspelled.
# One way to do that is to find words in the book that don't appear in a list of valid words.
# In previous chapters, we've used a list of words that are considered valid in word games like Scrabble.
# Now we'll use this list to spell-check Robert Louis Stevenson.
#
# We can think of this problem as set subtraction -- that is, we want to find all the words from one set (the words in the book) that are not in the other (the words in the list).

# %% [markdown]
# The following cell downloads the word list.

# %%
from google.colab import files
# !wget 'https://raw.githubusercontent.com/AllenDowney/ThinkPython/v3/words.txt'
files.download('words.txt')
# Out:
# --2025-05-22 04:57:09--  https://raw.githubusercontent.com/AllenDowney/ThinkPython/v3/words.txt
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1130294 (1.1M) [text/plain]
# Saving to: ‘words.txt’
#
# words.txt           100%[===================>]   1.08M  --.-KB/s    in 0.06s
#
# 2025-05-22 04:57:09 (18.2 MB/s) - ‘words.txt’ saved [1130294/1130294]

# %% [markdown]
# As we've done before, we can read the contents of `words.txt` and split it into a list of strings.

# %%
word_list = open('words.txt').read().split()

# %% [markdown]
# The we'll store the words as keys in a dictionary so we can use the `in` operator to check quickly whether a word is valid.

# %%
valid_words = {}
for word in word_list:
    valid_words[word] = 1

# %% [markdown]
# Now, to identify words that appear in the book but not in the word list, we'll use `subtract`, which takes two dictionaries as parameters and returns a new dictionary that contains all the keys from one that are not in the other.

# %%
def subtract(d1, d2):
    res = {}
    for key in d1:
        if key not in d2:
            res[key] = d1[key]
    return res

# %% [markdown]
# Here's how we use it.

# %%
diff = subtract(word_counter, valid_words)

# %% [markdown]
# To get a sample of words that might be misspelled, we can print the most common words in `diff`.

# %%
print_most_common(diff)
# Out:
# 640	i
# 628	a
# 128	utterson
# 124	mr
# 98	hyde

# %% [markdown]
# The most common "misspelled" words are mostly names and a few single-letter words (Mr. Utterson is Dr. Jekyll's friend and lawyer).
#
# If we select words that only appear once, they are more likely to be actual misspellings.
# We can do that by looping through the items and making a list of words with frequency `1`.

# %%
singletons = []
for word, freq in diff.items():
    if freq == 1:
        singletons.append(word)

# %% [markdown]
# Here are the last few elements of the list.

# %%
singletons[-5:]
# Out:
# ['gesticulated', 'abjection', 'circumscription', 'reindue', 'fearstruck']

# %% [markdown]
# Most of them are valid words that are not in the word list.
# But `'reindue'` appears to be a misspelling of `'reinduce'`, so at least we found one legitimate error.

# %% [markdown]
# ## Random numbers
#
# As a step toward Markov text generation, next we'll choose a random sequence of words from `word_counter`.
# But first let's talk about randomness.
#
# Given the same inputs, most computer programs are **deterministic**, which means they generate the same outputs every time.
# Determinism is usually a good thing, since we expect the same calculation to yield the same result.
# For some applications, though, we want the computer to be unpredictable.
# Games are one example, but there are more.
#
# Making a program truly nondeterministic turns out to be difficult, but there are ways to fake it.
# One is to use algorithms that generate **pseudorandom** numbers.
# Pseudorandom numbers are not truly random because they are generated by a deterministic computation, but just by looking at the numbers it is all but impossible to distinguish them from random.
#
# The `random` module provides functions that generate pseudorandom numbers -- which I will simply call "random" from here on.
# We can import it like this.

# %%
import random

# %%
# this cell initializes the random number generator so it
# generates the same sequence each time the notebook runs.

random.seed(4)

# %% [markdown]
# The `random` module provides a function called `choice` that chooses an element from a list at random, with every element having the same probability of being chosen.

# %%
t = [1, 2, 3]
random.choice(t)
# Out:
# 2

# %% [markdown]
# If you call the function again, you might get the same element again, or a different one.

# %%
random.choice(t)
# Out:
# 1

# %% [markdown]
# In the long run, we expect to get every element about the same number of times.
#
# If you use `choice` with a dictionary, you get a `KeyError`.

# %%
# %%expect KeyError

random.choice(word_counter)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-46-fd0ed1907219> in <cell line: 0>()
#       1 # %%expect KeyError
#       2
# ----> 3 random.choice(word_counter)
#
# /usr/lib/python3.11/random.py in choice(self, seq)
#     372         if not len(seq):
#     373             raise IndexError('Cannot choose from an empty sequence')
# --> 374         return seq[self._randbelow(len(seq))]
#     375
#     376     def shuffle(self, x):
#
# KeyError: 2954

# %% [markdown]
# To choose a random key, you have to put the keys in a list and then call `choice`.

# %%
words = list(word_counter)
random.choice(words)
# Out:
# 'listen'

# %% [markdown]
# If we generate a random sequence of words, it doesn't make much sense.

# %%
for i in range(6):
    word = random.choice(words)
    print(word, end=' ')
# Out:
# relieved apocryphal nor busy spoke jumped

# %% [markdown]
# Part of the problem is that we are not taking into account that some words are more common than others.
# The results will be better if we choose words with different "weights", so that some are chosen more often than others.
#
# If we use the values from `word_counter` as weights, each word is chosen with a probability that depends on its frequency.

# %%
weights = word_counter.values()

# %% [markdown]
# The `random` module provides another function called `choices` that takes weights as an optional argument.

# %%
random.choices(words, weights=weights)
# Out:
# ['business']

# %% [markdown]
# And it takes another optional argument, `k`, that specifies the number of words to select.

# %%
random_words = random.choices(words, weights=weights, k=6)
random_words
# Out:
# ['to', 'peep', 'the', 'what', 'he', 'pythias']

# %% [markdown]
# The result is a list of strings that we can join into something that's looks more like a sentence.

# %%
' '.join(random_words)
# Out:
# 'to peep the what he pythias'

# %% [markdown]
# If you choose words from the book at random, you get a sense of the vocabulary, but a series of random words seldom makes sense because there is no relationship between successive words.
# For example, in a real sentence you expect an article like "the" to be followed by an adjective or a noun, and probably not a verb or adverb.
# So the next step is to look at these relationships between words.

# %% [markdown]
# ## Bigrams
#
# Instead of looking at one word at a time, now we'll look at sequences of two words, which are called **bigrams**.
# A sequence of three words is called a **trigram**, and a sequence with some unspecified number of words is called an **n-gram**.
#
# Let's write a program that finds all of the bigrams in the book and the number of times each one appears.
# To store the results, we'll use a dictionary where
#
# * The keys are tuples of strings that represent bigrams, and
#
# * The values are integers that represent frequencies.
#
# Let's call it `bigram_counter`.

# %%
bigram_counter = {}

# %% [markdown]
# The following function takes a list of two strings as a parameter.
# First it makes a tuple of the two strings, which can be used as a key in a dictionary.
# Then it adds the key to `bigram_counter`, if it doesn't exist, or increments the frequency if it does.

# %%
def count_bigram(bigram):
    key = tuple(bigram)
    if key not in bigram_counter:
        bigram_counter[key] = 1
    else:
        bigram_counter[key] += 1

# %% [markdown]
# As we go through the book, we have to keep track of each pair of consecutive words.
# So if we see the sequence "man is not truly one", we would add the bigrams "man is", "is not", "not truly", and so on.
#
# To keep track of these bigrams, we'll use a list called `window`, because it is like a window that slides over the pages of the book, showing only two words at a time.
# Initially, `window` is empty.

# %%
window = []

# %% [markdown]
# We'll use the following function to process the words one at a time.

# %%
def process_word(word):
    window.append(word)

    if len(window) == 2:
        count_bigram(window)
        window.pop(0)

# %% [markdown]
# The first time this function is called, it appends the given word to `window`.
# Since there is only one word in the window, we don't have a bigram yet, so the function ends.
#
# The second time it's called -- and every time thereafter -- it appends a second word to `window`.
# Since there are two words in the window, it calls `count_bigram` to keep track of how many times each bigram appears.
# Then it uses `pop` to remove the first word from the window.
#
# The following program loops through the words in the book and processes them one at a time.

# %%
for line in open(filename):
    for word in split_line(line):
        word = clean_word(word)
        process_word(word)

# %% [markdown]
# The result is a dictionary that maps from each bigram to the number of times it appears.
# We can use `print_most_common` to see the most common bigrams.

# %%
print_most_common(bigram_counter)
# Out:
# 178	('of', 'the')
# 139	('in', 'the')
# 94	('it', 'was')
# 80	('and', 'the')
# 73	('to', 'the')

# %% [markdown]
# Looking at these results, we can get a sense of which pairs of words are most likely to appear together.
# We can also use the results to generate random text, like this.

# %%
random.seed(0)

# %%
bigrams = list(bigram_counter)
weights = bigram_counter.values()
random_bigrams = random.choices(bigrams, weights=weights, k=6)

# %% [markdown]
# `bigrams` is a list of the bigrams that appear in the books.
# `weights` is a list of their frequencies, so `random_bigrams` is a sample where the probability a bigram is selected is proportional to its frequency.
#
# Here are the results.

# %%
for pair in random_bigrams:
    print(' '.join(pair), end=' ')
# Out:
# to suggest this preface to detain fact is above all the laboratory

# %% [markdown]
# This way of generating text is better than choosing random words, but still doesn't make a lot of sense.

# %% [markdown]
# ## Markov analysis
#
# We can do better with Markov chain text analysis, which computes, for each word in a text, the list of words that come next.
# As an example, we'll analyze these lyrics from the Monty Python song *Eric, the Half a Bee*:

# %%
song = """
Half a bee, philosophically,
Must, ipso facto, half not be.
But half the bee has got to be
Vis a vis, its entity. D'you see?
"""

# %% [markdown]
# To store the results, we'll use a dictionary that maps from each word to the list of words that follow it.

# %%
successor_map = {}

# %% [markdown]
# As an example, let's start with the first two words of the song.

# %%
first = 'half'
second = 'a'

# %% [markdown]
# If the first word is not in `successor_map`, we have to add a new item that maps from the first word to a list containing the second word.

# %%
successor_map[first] = [second]
successor_map
# Out:
# {'half': ['a']}

# %% [markdown]
# If the first word is already in the dictionary, we can look it up to get the list of successors we've seen so far, and append the new one.

# %%
first = 'half'
second = 'not'

successor_map[first].append(second)
successor_map
# Out:
# {'half': ['a', 'not']}

# %% [markdown]
# The following function encapsulates these steps.

# %%
def add_bigram(bigram):
    first, second = bigram

    if first not in successor_map:
        successor_map[first] = [second]
    else:
        successor_map[first].append(second)

# %% [markdown]
# If the same bigram appears more that once, the second word is added to the list more than once.
# In this way, `successor_map` keeps track of how many times each successor appears.
#
# As we did in the previous section, we'll use a list called `window` to store pairs of consecutive words.
# And we'll use the following function to process the words one at a time.

# %%
def process_word_bigram(word):
    window.append(word)

    if len(window) == 2:
        add_bigram(window)
        window.pop(0)

# %% [markdown]
# Here's how we use it to process the words in the song.

# %%
successor_map = {}
window = []

for word in song.split():
    word = clean_word(word)
    process_word_bigram(word)

# %% [markdown]
# And here are the results.

# %%
successor_map
# Out:
# {'half': ['a', 'not', 'the'],
#  'a': ['bee', 'vis'],
#  'bee': ['philosophically', 'has'],
#  'philosophically': ['must'],
#  'must': ['ipso'],
#  'ipso': ['facto'],
#  'facto': ['half'],
#  'not': ['be'],
#  'be': ['but', 'vis'],
#  'but': ['half'],
#  'the': ['bee'],
#  'has': ['got'],
#  'got': ['to'],
#  'to': ['be'],
#  'vis': ['a', 'its'],
#  'its': ['entity'],
#  'entity': ["d'you"],
#  "d'you": ['see']}

# %% [markdown]
# The word `'half'` can be followed by `'a'`, `'not'`, or `'the'`.
# The word `'a'` can be followed by `'bee'` or `'vis'`.
# Most of the other words appear only once, so they are followed by only a single word.
#
# Now let's analyze the book.

# %%
successor_map = {}
window = []

for line in open(filename):
    for word in split_line(line):
        word = clean_word(word)
        process_word_bigram(word)
successor_map
# Out:
# {'the': ['strange',
#   'door',
#   'carew',
#   'letter',
#   'window',
#   'last',
#   'case',
#   'door',
#   'lawyer',
#   'wine',
#   'after-dinner',
#   'acts',
#   'theatre',
#   'doors',
#   'high',
#   'devil',
#   'last',
#   'last',
#   'lives',
#   'feat',
#   'best',
#   'mark',
#   'hands',
#   'lawyer’s',
#   'longest',
#   'growth',
#   'object',
#   'bond',
#   'well-known',
#   'appearance',
#   'two',
#   'greatest',
#   'chief',
#   'calls',
#   'street',
#   'weekdays',
#   'inhabitants',
#   'surplus',
#   'shop',
#   'street',
#   'eye',
#   'passenger',
#   'left',
#   'line',
#   'entry',
#   'street',
#   'lower',
#   'upper',
#   'marks',
#   'door',
#   'recess',
#   'panels',
#   'steps',
#   'schoolboy',
#   'mouldings',
#   'lawyer',
#   'other',
#   'by-street',
#   'entry',
#   'former',
#   'affirmative',
#   'end',
#   'world',
#   'folks',
#   'sight',
#   'other',
#   'two',
#   'corner',
#   'horrible',
#   'thing',
#   'man',
#   'child’s',
#   'ground',
#   'screaming',
#   'sweat',
#   'people',
#   'girl’s',
#   'doctor',
#   'child',
#   'worse',
#   'sawbones',
#   'child’s',
#   'doctor’s',
#   'usual',
#   'rest',
#   'desire',
#   'question',
#   'next',
#   'man',
#   'other',
#   'time',
#   'women',
#   'man',
#   'middle',
#   'child’s',
#   'lot',
#   'next',
#   'money',
#   'door',
#   'matter',
#   'balance',
#   'points',
#   'figure',
#   'signature',
#   'liberty',
#   'whole',
#   'morning',
#   'banks',
#   'cheque',
#   'doctor',
#   'child’s',
#   'rest',
#   'night',
#   'bank',
#   'cheque',
#   'cheque',
#   'person',
#   'cheque',
#   'very',
#   'proprieties',
#   'nose',
#   'capers',
#   'place',
#   'door',
#   'words',
#   'drawer',
#   'cheque',
#   'place',
#   'door',
#   'reply',
#   'style',
#   'day',
#   'top',
#   'stone',
#   'last',
#   'head',
#   'family',
#   'more',
#   'less',
#   'lawyer',
#   'place',
#   'gentleman',
#   'court',
#   'first',
#   'windows',
#   'buildings',
#   'court',
#   'pair',
#   'lawyer',
#   'name',
#   'child',
#   'name',
#   'point',
#   'way',
#   'fact',
#   'name',
#   'other',
#   'other',
#   'fellow',
#   'young',
#   'lawyer',
#   'fire',
#   'clock',
#   'neighbouring',
#   'hour',
#   'cloth',
#   'most',
#   'envelope',
#   'will',
#   'least',
#   'making',
#   'decease',
#   'hands',
#   'said',
#   'said',
#   'payment',
#   'members',
#   'doctor’s',
#   'lawyer’s',
#   'sane',
#   'fanciful',
#   'immodest',
#   'name',
#   'shifting',
#   'sudden',
#   'obnoxious',
#   'safe',
#   'direction',
#   'great',
#   'solemn',
#   'door',
#   'dining-room',
#   'geniality',
#   'way',
#   'man',
#   'eye',
#   'lawyer',
#   'subject',
#   'two',
#   'friends',
#   'reply',
#   'man',
#   'doctor',
#   'matter',
#   'question',
#   'amount',
#   'lawyer',
#   'great',
#   'small',
#   'morning',
#   'bells',
#   'church',
#   'problem',
#   'intellectual',
#   'gross',
#   'night',
#   'curtained',
#   'great',
#   'figure',
#   'doctor’s',
#   'child',
#   'door',
#   'curtains',
#   'bed',
#   'sleeper',
#   'figure',
#   'lawyer',
#   'more',
#   'more',
#   'figure',
#   'lawyer’s',
#   'features',
#   'real',
#   'mystery',
#   'habit',
#   'startling',
#   'will',
#   'face',
#   'mind',
#   'unimpressionable',
#   'door',
#   'by-street',
#   'morning',
#   'face',
#   'fogged',
#   'lawyer',
#   'air',
#   'streets',
#   'lamps',
#   'shops',
#   'by-street',
#   'low',
#   'houses',
#   'roadway',
#   'rumour',
#   'approach',
#   'course',
#   'quaint',
#   'footfalls',
#   'vast',
#   'city',
#   'entry',
#   'court',
#   'steps',
#   'end',
#   'street',
#   'lawyer',
#   'entry',
#   'look',
#   'watcher’s',
#   'door',
#   'roadway',
#   'shoulder',
#   'breath',
#   'lawyer',
#   'face',
#   'lawyer',
#   'key',
#   'other',
#   'lawyer',
#   'pair',
#   'will',
#   'address',
#   'other',
#   'reply',
#   'lawyer',
#   'other',
#   'next',
#   'door',
#   'house',
#   'lawyer',
#   'picture',
#   'street',
#   'problem',
#   'lawyer',
#   'hitherto',
#   'perplexed',
#   'man',
#   'old',
#   'mere',
#   'last',
#   'corner',
#   'by-street',
#   'most',
#   'agents',
#   'corner',
#   'door',
#   'fanlight',
#   'door',
#   'lawyer',
#   'visitor',
#   'fashion',
#   'fire',
#   'dining-room',
#   'lawyer',
#   'tall',
#   'doctor’s',
#   'pleasantest',
#   'face',
#   'gloom',
#   'flickering',
#   'firelight',
#   'polished',
#   'uneasy',
#   'shadow',
#   'roof',
#   'old',
#   'servant',
#   'other',
#   'butler',
#   'house',
#   'laboratory',
#   'lawyer',
#   'law',
#   'ghost',
#   'cancer',
#   'fault',
#   'lawyer',
#   'thought',
#   'corners',
#   'rolls',
#   'dust',
#   'many',
#   'many',
#   'look',
#   'danger',
#   'existence',
#   'will',
#   'wheel',
#   'strange',
#   'will',
#   'doctor',
#   'others',
#   'dry',
#   'light-hearted',
#   'threshold',
#   'man’s',
#   'expense',
#   'opposite',
#   'fire',
#   'latter',
#   'topic',
#   'doctor',
#   'fresh',
#   'doctor',
#   'lawyer',
#   'large',
#   'very',
#   'doctor',
#   'doctor',
#   'choice',
#   'moment',
#   'fire',
#   'last',
#   'doctor',
#   'lawyer',
#   'other’s',
#   'carew',
#   'month',
#   'more',
#   'high',
#   'victim',
#   'details',
#   'river',
#   'city',
#   'small',
#   'early',
#   'night',
#   'lane',
#   'maid’s',
#   'full',
#   'window',
#   'world',
#   'lane',
#   'maid’s',
#   'older',
#   'other',
#   'subject',
#   'moon',
#   'girl',
#   'other',
#   'cane',
#   'maid',
#   'old',
#   'air',
#   'earth',
#   'bones',
#   'body',
#   'roadway',
#   'horror',
#   'maid',
#   'police',
#   'murderer',
#   'middle',
#   'lane',
#   'stick',
#   'deed',
#   'middle',
#   'stress',
#   'neighbouring',
#   'other',
#   'murderer',
#   'victim',
#   'post',
#   'name',
#   'lawyer',
#   'next',
#   'circumstances',
#   'body',
#   'kindness',
#   'same',
#   'police',
#   'body',
#   'cell',
#   'officer',
#   'next',
#   'man',
#   'maid',
#   'broken',
#   'name',
#   'stick',
#   'maid',
#   'officer',
#   'morning',
#   'first',
#   'season',
#   'wind',
#   'cab',
#   'back-end',
#   'light',
#   'fog',
#   'swirling',
#   'dismal',
#   'lawyer’s',
#   'thoughts',
#   'gloomiest',
#   'companion',
#   'law',
#   'law’s',
#   'most',
#   'cab',
#   'address',
#   'fog',
#   'retail',
#   'doorways',
#   'next',
#   'fog',
#   'home',
#   'door',
#   'lawyer',
#   'woman',
#   'woman’s',
#   'inspector',
#   'latter',
#   'whole',
#   'house',
#   'old',
#   'plate',
#   'napery',
#   'walls',
#   'carpets',
#   'rooms',
#   'floor',
#   'hearth',
#   'inspector',
#   'butt',
#   'action',
#   'fire',
#   'other',
#   'stick',
#   'door',
#   'officer',
#   'bank',
#   'murderer’s',
#   'stick',
#   'cheque',
#   'man',
#   'bank',
#   'handbills',
#   'master',
#   'servant',
#   'few',
#   'haunting',
#   'fugitive',
#   'letter',
#   'afternoon',
#   'kitchen',
#   'building',
#   'laboratory',
#   'doctor',
#   'house',
#   'heirs',
#   'destination',
#   'block',
#   'bottom',
#   'garden',
#   'first',
#   'lawyer',
#   'dingy',
#   'theatre',
#   'tables',
#   'floor',
#   'light',
#   'foggy',
#   'further',
#   'doctor’s',
#   'court',
#   'fire',
#   'grate',
#   'chimney',
#   'houses',
#   'fog',
#   'warmth',
#   'news',
#   'doctor',
#   'square',
#   'lawyer',
#   'doctor',
#   'lawyer',
#   'police',
#   'lawyer',
#   'other',
#   'letter',
#   'letter',
#   'writer’s',
#   'lawyer',
#   'intimacy',
#   'envelope',
#   'note',
#   'reply',
#   'lawyer',
#   'terms',
#   'doctor',
#   'purpose',
#   'doctor',
#   'lawyer',
#   'bye',
#   'messenger',
#   'visitor',
#   'letter',
#   'laboratory',
#   'cabinet',
#   'more',
#   'newsboys',
#   'footways',
#   'funeral',
#   'good',
#   'eddy',
#   'scandal',
#   'other',
#   'fire',
#   'foundations',
#   'fog',
#   'wing',
#   'drowned',
#   'lamps',
#   'muffle',
#   'procession',
#   'town’s',
#   'great',
#   'room',
#   'bottle',
#   'acids',
#   'imperial',
#   'colour',
#   'glow',
#   'fogs',
#   'lawyer',
#   'doctor’s',
#   'house',
#   'step',
#   'clerk',
#   'man',
#   'best',
#   'lawyer',
#   'servant',
#   'clerk',
#   'writing',
#   'clerk',
#   'two',
#   'clerk',
#   'two',
#   'master',
#   'clerk',
#   'note',
#   'death',
#   'ken',
#   'police',
#   'man’s',
#   'hatred',
#   'time',
#   'house',
#   'morning',
#   'murder',
#   'hotness',
#   'death',
#   'disappearance',
#   'open',
#   'doctor',
#   '8th',
#   'doctor’s',
#   'face',
#   'host',
#   'other',
#   'old',
#   'trio',
#   '12th',
#   '14th',
#   'door',
#   'lawyer',
#   'doctor',
#   'house',
#   '15th',
#   'last',
#   'fifth',
#   'sixth',
#   'change',
#   'doctor’s',
#   'rosy',
#   'lawyer’s',
#   'eye',
#   'mind',
#   'doctor',
#   'knowledge',
#   'lawyer',
#   'reply',
#   'right',
#   'meantime',
#   'house',
#   'cause',
#   'next',
#   'quarrel',
#   'chief',
#   'chief',
#   'dark',
#   'doctor',
#   'prospect',
#   'whole',
#   'night',
#   'funeral',
#   'door',
#   'light',
#   'hand',
#   'seal',
#   'hands',
#   'lawyer',
#   'contents',
#   'fear',
#   'seal',
#   'cover',
#   'death',
#   'mad',
#   'idea',
#   'name',
#   'will',
#   'sinister',
#   'man',
#   'hand',
#   'trustee',
#   'prohibition',
#   'bottom',
#   'packet',
#   'inmost',
#   'society',
#   'same',
#   'doorstep',
#   'air',
#   'open',
#   'doctor',
#   'cabinet',
#   'laboratory',
#   'unvarying',
#   'frequency',
#   'window',
#   'by-street',
#   'door',
#   'one',
#   'other',
#   'way',
#   'court',
#   'windows',
#   'truth',
#   'presence',
#   'court',
#   'sky',
#   'middle',
#   'three',
#   'air',
#   'doctor',
#   'lawyer',
#   'circulation',
#   'other',
#   'place',
#   'lawyer',
#   'best',
#   'doctor',
#   'words',
#   'smile',
#   'very',
#   'two',
#   'window',
#   'court',
#   'by-street',
#   'last',
#   'doctor',
#   'man',
#   'lawyer',
#   'doctor’s',
#   'cabinet',
#   'lawyer',
#   'question',
#   'man’s',
#   'worse',
#   'moment',
#   'lawyer',
#   'face',
#   'glass',
#   'floor',
#   'lawyer',
#   'lawyer',
#   'man',
#   'answer',
#   'greatness',
#   'relief',
#   'butler’s',
#   'wine',
#   'wind',
#   'most',
#   'wind',
#   'blood',
#   'face',
#   'streets',
#   'square',
#   'thin',
#   'garden',
#   'railing',
#   'way',
#   'middle',
#   'pavement',
#   'biting',
#   'hurry',
#   'dews',
#   'moisture',
#   'lawyer',
#   'servant',
#   'door',
#   'chain',
#   'door',
#   'hall',
#   'fire',
#   'hearth',
#   'whole',
#   'servants',
#   'sight',
#   'housemaid',
#   'cook',
#   'lawyer',
#   'maid',
#   'girl',
#   'note',
#   'inner',
#   'butler',
#   'knife-boy',
#   'way',
#   'back',
#   'butler',
#   'laboratory',
#   'surgical',
#   'foot',
#   'stair',
#   'candle',
#   'steps',
#   'red',
#   'cabinet',
#   'lawyer',
#   'yard',
#   'great',
#   'fire',
#   'beetles',
#   'floor',
#   'eyes',
#   'lawyer',
#   'butler',
#   'name',
#   'murderer',
#   'master’s',
#   'stair',
#   'very',
#   'same',
#   'wholesale',
#   'stuff',
#   'lawyer',
#   'candle',
#   'year',
#   'same',
#   'importance',
#   'letter',
#   'pen',
#   'writer’s',
#   'old',
#   'man',
#   'doctor’s',
#   'lawyer',
#   'servant',
#   'theatre',
#   'garden',
#   'cabinet',
#   'far',
#   'room',
#   'crates',
#   'cabinet',
#   'hair',
#   'man',
#   'sufferer',
#   'alteration',
#   'mask',
#   'avoidance',
#   'poor',
#   'butler',
#   'truth',
#   'cabinet',
#   'mask',
#   'belief',
#   'lawyer',
#   'butler',
#   'second',
#   'undaunted',
#   'lawyer',
#   'theatre',
#   'kitchen',
#   'lawyer',
#   'butler',
#   'other',
#   'creature',
#   'answer',
#   'same',
#   'same',
#   'laboratory',
#   'time',
#   'murder',
#   'key',
#   'lawyer',
#   'rest',
#   'chemicals',
#   'cabinet',
#   'lawyer',
#   'same',
#   'footman',
#   'summons',
#   'lawyer',
#   'cabinet',
#   'blame',
#   'back',
#   'boy',
#   'corner',
#   'laboratory',
#   'lawyer',
#   'poker',
#   'way',
#   'yard',
#   'scud',
#   'moon',
#   'wind',
#   'light',
#   'candle',
#   'shelter',
#   'theatre',
#   'stillness',
#   'sounds',
#   'cabinet',
#   'better',
#   'night',
#   'chemist',
#   'doctor’s',
#   'steps',
#   'heavy',
#   'lawyer',
#   'butler',
#   'ten',
#   'axe',
#   'candle',
#   'nearest',
#   'attack',
#   'quiet',
#   'night',
#   'voice',
#   'door',
#   'axe',
#   'blow',
#   'building',
#   'red',
#   'lock',
#   'cabinet',
#   'axe',
#   'panels',
#   'frame',
#   'blow',
#   'wood',
#   'fittings',
#   'fifth',
#   'lock',
#   'wreck',
#   'door',
#   'carpet',
#   'besiegers',
#   'stillness',
#   'cabinet',
#   'quiet',
#   'hearth',
#   'kettle',
#   'business',
#   'fire',
#   'things',
#   'quietest',
#   'glazed',
#   'most',
#   'middle',
#   'body',
#   'face',
#   'doctor’s',
#   'cords',
#   'crushed',
#   'hand',
#   'strong',
#   'air',
#   'body',
#   'body',
#   'far',
#   'building',
#   'theatre',
#   'whole',
#   'cabinet',
#   'court',
#   'theatre',
#   'door',
#   'by-street',
#   'cabinet',
#   'dust',
#   'cellar',
#   'times',
#   'surgeon',
#   'door',
#   'uselessness',
#   'fall',
#   'entrance',
#   'flags',
#   'corridor',
#   'sound',
#   'door',
#   'by-street',
#   'flags',
#   'key',
#   'lawyer',
#   'fractures',
#   'two',
#   'lawyer',
#   'cabinet',
#   'stair',
#   'dead',
#   'contents',
#   'cabinet',
#   'unhappy',
#   'same',
#   'kettle',
#   'fireside',
#   'easy-chair',
#   'tea',
#   'sitter’s',
#   'very',
#   'cup',
#   'tea',
#   'course',
#   'chamber',
#   'searchers',
#   'cheval-glass',
#   'rosy',
#   'roof',
#   'fire',
#   'glazed',
#   'presses',
#   ...],
#  'strange': ['case',
#   'the',
#   'preference',
#   'clauses',
#   'a',
#   'one',
#   'conflagration',
#   'in',
#   'a',
#   'associates',
#   'tale',
#   'note',
#   'circumstances',
#   'things',
#   'place',
#   'to',
#   'in',
#   'immunities',
#   'array',
#   'as'],
#  'case': ['of',
#   'incident',
#   'story',
#   'was',
#   'of',
#   'of',
#   'nearly',
#   'of',
#   'of',
#   'of',
#   'can',
#   'dear',
#   'of',
#   'i',
#   'i',
#   'to'],
#  'of': ['dr',
#   'the',
#   'the',
#   'dr',
#   'the',
#   'the',
#   'a',
#   'the',
#   'his',
#   'one',
#   'spirits',
#   'downgoing',
#   'change',
#   'good-nature',
#   'a',
#   'opportunity',
#   'his',
#   'time',
#   'a',
#   'each',
#   'pleasure',
#   'business',
#   'these',
#   'london',
#   'their',
#   'invitation',
#   'smiling',
#   'passage',
#   'note',
#   'the',
#   'a',
#   'building',
#   'discoloured',
#   'prolonged',
#   'the',
#   'the',
#   'voice',
#   'the',
#   'a',
#   'town',
#   'mind',
#   'a',
#   'maybe',
#   'the',
#   'no',
#   'us',
#   'the',
#   'this',
#   'london',
#   'such',
#   'black',
#   'this',
#   'us',
#   'ten',
#   'the',
#   'my',
#   'pointing',
#   'the',
#   'it',
#   'the',
#   'your',
#   'the',
#   'his',
#   'musing',
#   'the',
#   'the',
#   'the',
#   'judgment',
#   'a',
#   'is',
#   'mine',
#   'that',
#   'my',
#   'yours',
#   'that',
#   'the',
#   'hyde',
#   'a',
#   'deformity',
#   'the',
#   'it',
#   'memory',
#   'consideration',
#   'himself',
#   'the',
#   'sullenness',
#   'my',
#   'a',
#   'some',
#   'the',
#   'twelve',
#   'it',
#   'it',
#   'it',
#   'the',
#   'henry',
#   'his',
#   'dr',
#   'a',
#   'the',
#   'the',
#   'life',
#   'mr',
#   'which',
#   'the',
#   'a',
#   'cavendish',
#   'medicine',
#   'delay',
#   'hair',
#   'mr',
#   'the',
#   'themselves',
#   'each',
#   'that',
#   'him',
#   'common',
#   'course',
#   'the',
#   'temper',
#   'a',
#   'science',
#   'no',
#   'conveyancing',
#   'his',
#   'him',
#   'information',
#   'the',
#   'little',
#   'the',
#   'the',
#   'lighted',
#   'the',
#   'lamps',
#   'a',
#   'the',
#   'a',
#   'a',
#   'her',
#   'that',
#   'the',
#   'lamplighted',
#   'the',
#   'mysterious',
#   'the',
#   'a',
#   'mercy',
#   'the',
#   'enduring',
#   'shops',
#   'the',
#   'solitude',
#   'light',
#   'the',
#   'london',
#   'the',
#   'the',
#   'the',
#   'any',
#   'an',
#   'his',
#   'a',
#   'the',
#   'success',
#   'the',
#   'the',
#   'man',
#   'him',
#   'the',
#   'dr',
#   'gaunt',
#   'my',
#   'defiance',
#   'a',
#   'the',
#   'the',
#   'anger',
#   'disquietude',
#   'a',
#   'deformity',
#   'murderous',
#   'timidity',
#   'these',
#   'dr',
#   'a',
#   'your',
#   'ancient',
#   'men',
#   'obscure',
#   'this',
#   'wealth',
#   'a',
#   'oak',
#   'his',
#   'it',
#   'hyde',
#   'life',
#   'his',
#   'the',
#   'the',
#   'his',
#   'trust',
#   'him',
#   'the',
#   'god',
#   'limitations',
#   'some',
#   'some',
#   'memory',
#   'an',
#   'their',
#   'hope',
#   'his',
#   'him',
#   'this',
#   'it',
#   'the',
#   'the',
#   'his',
#   'good',
#   'times',
#   'gaiety',
#   'the',
#   'fifty',
#   'a',
#   'capacity',
#   'yours',
#   'him',
#   'it',
#   'young',
#   'dr',
#   'manner',
#   'those',
#   'this',
#   'it',
#   'you',
#   'you',
#   'mr',
#   'you',
#   'october',
#   'singular',
#   'the',
#   'the',
#   'musing',
#   'the',
#   'an',
#   'politeness',
#   'his',
#   'great',
#   'disposition',
#   'a',
#   'a',
#   'anger',
#   'one',
#   'all',
#   'blows',
#   'these',
#   'the',
#   'some',
#   'this',
#   'mr',
#   'bed',
#   'noise',
#   'hyde',
#   'small',
#   'the',
#   'degrees',
#   'twilight',
#   'evening',
#   'a',
#   'some',
#   'daylight',
#   'soho',
#   'darkness',
#   'some',
#   'his',
#   'the',
#   'his',
#   'some',
#   'that',
#   'the',
#   'penny',
#   'many',
#   'henry',
#   'a',
#   'a',
#   'scotland',
#   'odious',
#   'the',
#   'rooms',
#   'silver',
#   'a',
#   'many',
#   'having',
#   'grey',
#   'a',
#   'the',
#   'the',
#   'accomplishment',
#   'the',
#   'unexpressed',
#   'the',
#   'a',
#   'the',
#   'the',
#   'his',
#   'strangeness',
#   'stairs',
#   'the',
#   'him',
#   'him',
#   'hyde',
#   'my',
#   'escape',
#   'his',
#   'faintness',
#   'an',
#   'one',
#   'another',
#   'the',
#   'his',
#   'a',
#   'his',
#   'these',
#   'the',
#   'a',
#   'hot',
#   'london',
#   'mr',
#   'handwriting',
#   'counsel',
#   'public',
#   'course',
#   'paper',
#   'this',
#   'dr',
#   'pounds',
#   'sir',
#   'the',
#   'the',
#   'his',
#   'the',
#   'his',
#   'his',
#   'the',
#   'his',
#   'the',
#   'his',
#   'sir',
#   'thinking',
#   'mr',
#   'his',
#   'service',
#   'january',
#   'the',
#   'solitude',
#   'a',
#   'manner',
#   'the',
#   'great',
#   'weeks',
#   'dr',
#   'this',
#   'other',
#   'this',
#   'his',
#   'this',
#   'extreme',
#   'sinners',
#   'sufferers',
#   'hyde',
#   'a',
#   'mind',
#   'his',
#   'lanyon’s',
#   'his',
#   'a',
#   'his',
#   'g',
#   'his',
#   'dr',
#   'a',
#   'henry',
#   'the',
#   'lanyon',
#   'these',
#   'his',
#   'his',
#   'him',
#   'the',
#   'voluntary',
#   'spirits',
#   'these',
#   'his',
#   'the',
#   'mr',
#   'repulsion',
#   'a',
#   'premature',
#   'the',
#   'mien',
#   'his',
#   'such',
#   'the',
#   'life',
#   'wine',
#   'i’ve',
#   'wine',
#   'the',
#   'the',
#   'march',
#   'the',
#   'passengers',
#   'london',
#   'so',
#   'calamity',
#   'wind',
#   'the',
#   'the',
#   'his',
#   'exertion',
#   'some',
#   'the',
#   'sheep',
#   'mr',
#   'accent',
#   'her',
#   'dreadful',
#   'crates',
#   'the',
#   'the',
#   'something',
#   'god',
#   'him',
#   'medicine',
#   'paper',
#   'these',
#   'the',
#   'this',
#   'the',
#   'the',
#   'write',
#   'the',
#   'cry',
#   'those',
#   'his',
#   'his',
#   'which',
#   'ultimate',
#   'mottled',
#   'a',
#   'a',
#   'my',
#   'my',
#   'it',
#   'some',
#   'the',
#   'the',
#   'us',
#   'cold',
#   'what',
#   'that',
#   'you',
#   'it',
#   'good',
#   'building',
#   'the',
#   'the',
#   'a',
#   'the',
#   'a',
#   'it',
#   'henry',
#   'a',
#   'horror',
#   'packing',
#   'the',
#   'your',
#   'mere',
#   'excellent',
#   'the',
#   'chemicals',
#   'a',
#   'edward',
#   'the',
#   'his',
#   'life',
#   'kernels',
#   'a',
#   'your',
#   'the',
#   'stairs',
#   'the',
#   'the',
#   'further',
#   'a',
#   'cobweb',
#   'henry',
#   'the',
#   'the',
#   'chemical',
#   'some',
#   'a',
#   'their',
#   'the',
#   'the',
#   'papers',
#   'mr',
#   'death',
#   'gift',
#   'disappearance',
#   'the',
#   'edward',
#   'gabriel',
#   'all',
#   'in',
#   'my',
#   'your',
#   'this',
#   'the',
#   'january',
#   'my',
#   'correspondence',
#   'registration',
#   'my',
#   'an',
#   'my',
#   'mind',
#   'misdirecting',
#   'you',
#   'the',
#   'this',
#   'margin',
#   'one',
#   'those',
#   'capital',
#   'one',
#   'them',
#   'my',
#   'such',
#   'me',
#   'distress',
#   'the',
#   'henry',
#   'this',
#   'doubt',
#   'this',
#   'its',
#   'instruction',
#   'the',
#   'jekyll’s',
#   'the',
#   'a',
#   'a',
#   'smell',
#   'dates',
#   'many',
#   'several',
#   'exclamation',
#   'some',
#   'a',
#   'experiments',
#   'jekyll’s',
#   'practical',
#   'these',
#   'my',
#   'cerebral',
#   'self-defence',
#   'the',
#   'the',
#   'the',
#   'clearly',
#   'his',
#   'great',
#   'constitution',
#   'the',
#   'the',
#   'man',
#   'hatred',
#   'his',
#   'rich',
#   'the',
#   'the',
#   'a',
#   'a',
#   'your',
#   'my',
#   'the',
#   'my',
#   'my',
#   'your',
#   'business',
#   'some',
#   'his',
#   'the',
#   'his',
#   'despair',
#   'the',
#   'such',
#   'an',
#   'the',
#   'the',
#   'a',
#   'vapour',
#   'scrutiny',
#   'curiosity',
#   'you',
#   'service',
#   'riches',
#   'the',
#   'knowledge',
#   'satan',
#   'belief',
#   'inexplicable',
#   'our',
#   'transcendental',
#   'the',
#   'penitence',
#   'horror',
#   'hyde',
#   'the',
#   'carew',
#   'the',
#   'the',
#   'the',
#   'an',
#   'my',
#   'disposition',
#   'many',
#   'reflection',
#   'my',
#   'life',
#   'but',
#   'shame',
#   'my',
#   'men',
#   'good',
#   'life',
#   'religion',
#   'the',
#   'distress',
#   'me',
#   'day',
#   'knowledge',
#   'sorrow',
#   'my',
#   'the',
#   'my',
#   'my',
#   'multifarious',
#   'my',
#   'man',
#   'the',
#   'my',
#   'my',
#   'such',
#   'the',
#   'these',
#   'all',
#   'his',
#   'this',
#   'mankind',
#   'consciousness',
#   'this',
#   'a',
#   'my',
#   'our',
#   'certain',
#   'the',
#   'lower',
#   'practice',
#   'identity',
#   'an',
#   'exhibition',
#   'a',
#   'alarm',
#   'wholesale',
#   'a',
#   'courage',
#   'the',
#   'birth',
#   'a',
#   'a',
#   'disordered',
#   'the',
#   'obligation',
#   'the',
#   'this',
#   'these',
#   'these',
#   'the',
#   'my',
#   'slumber',
#   'that',
#   'edward',
#   'my',
#   'my',
#   'effort',
#   'the',
#   'the',
#   'man',
#   'deformity',
#   'no',
#   'a',
#   'welcome',
#   'the',
#   'edward',
#   'the',
#   'good',
#   'mankind',
#   'dissolution',
#   'henry',
#   'generous',
#   'death',
#   'a',
#   'the',
#   'my',
#   'philippi',
#   'whose',
#   'a',
#   'study',
#   'my',
#   'the',
#   'edward',
#   'dr',
#   'edward',
#   'my',
#   'genial',
#   'liberty',
#   'it',
#   'breath',
#   'edward',
#   'wonder',
#   'my',
#   'torture',
#   'stone',
#   'edward',
#   'conscience',
#   'the',
#   'entering',
#   'cruelty',
#   'a',
#   'your',
#   'henry',
#   'edward',
#   'fate',
#   'sir',
#   'my',
#   'my',
#   'the',
#   'the',
#   'edward',
#   'this',
#   'my',
#   'henry',
#   'a',
#   'a',
#   'hair',
#   'edward',
#   'wonder',
#   'cymbals',
#   'terror',
#   'stairs',
#   'what',
#   'relief',
#   'my',
#   'my',
#   'breakfasting',
#   'my',
#   'my',
#   'my',
#   'me',
#   'projecting',
#   'late',
#   'edward',
#   'a',
#   'blood',
#   'my',
#   'voluntary',
#   'edward',
#   'the',
#   'death',
#   'that',
#   'jekyll',
#   'late',
#   'my',
#   'hyde',
#   'late',
#   'abstinence',
#   'all',
#   'this',
#   'my',
#   'hyde',
#   'edward',
#   'such',
#   'an',
#   'my',
#   'conscience',
#   'course',
#   'hyde',
#   'moral',
#   'five',
#   'edward',
#   'a',
#   'impatience',
#   'my',
#   'that',
#   'all',
#   'us',
#   'steadiness',
#   'hell',
#   'glee',
#   'my',
#   'terror',
#   'these',
#   'evil',
#   'life',
#   'mind',
#   'the',
#   'transformation',
#   'gratitude',
#   'self-indulgence',
#   'childhood',
#   'my',
#   'unreality',
#   'the',
#   'hideous',
#   'my',
#   'this',
#   'joy',
#   'my',
#   'my',
#   'it',
#   'natural',
#   'hyde',
#   'the',
#   'refuge',
#   'all',
#   'some',
#   'the',
#   'this',
#   'purpose',
#   'my',
#   'me',
#   'resuscitating',
#   'that',
#   'temptation',
#   'my',
#   'winter',
#   'memory',
#   'their',
#   'that',
#   'a',
#   'my',
#   'danger',
#   'the',
#   'obligation',
#   'all',
#   'mankind',
#   'the',
#   'the',
#   'my',
#   'lanyon',
#   'his',
#   'my',
#   'which',
#   'devilish',
#   'his',
#   'murder',
#   'the',
#   'their',
#   'a',
#   'the',
#   'hell',
#   'the',
#   'lights',
#   'my',
#   'the',
#   'being',
#   'the',
#   'the',
#   'course',
#   'the',
#   'hope',
#   'the',
#   'my',
#   'hyde',
#   'gymnastics',
#   'the',
#   'jekyll',
#   'the',
#   'this',
#   'my',
#   'the',
#   'transformation',
#   'a',
#   'terror',
#   'life',
#   'hyde',
#   'jekyll',
#   'vital',
#   'that',
#   'the',
#   'consciousness',
#   'community',
#   'his',
#   'hyde',
#   'life',
#   'something',
#   'the',
#   'life',
#   'weakness',
#   'slumber',
#   'life',
#   'hyde',
#   'a',
#   'the',
#   'a',
#   'a',
#   'my',
#   'my',
#   'death',
#   'life',
#   'him',
#   'this',
#   'soul',
#   'despair',
#   'the',
#   'the',
#   'colour',
#   'the',
#   'the',
#   'a',
#   'great',
#   'change',
#   'writing',
#   'his',
#   'listening',
#   'menace',
#   'death',
#   'that'],
#  'dr': ['jekyll',
#   'jekyll',
#   'lanyon',
#   'lanyon’s',
#   'jekyll’s',
#   'jekyll’s',
#   'lanyon',
#   'lanyon',
#   'lanyon',
#   'jekyll’s',
#   'jekyll',
#   'fell',
#   'jekyll',
#   'jekyll',
#   'jekyll',
#   'jekyll',
#   'jekyll',
#   'jekyll',
#   'jekyll’s',
#   'jekyll',
#   'jekyll',
#   'jekyll',
#   'lanyon',
#   'jekyll',
#   'lanyon’s',
#   'jekyll',
#   'lanyon',
#   'henry',
#   'jekyll’s',
#   'jekyll',
#   'jekyll',
#   'jekyll',
#   'jekyll',
#   'j',
#   'j',
#   'jekyll',
#   'jekyll',
#   'lanyon’s',
#   'denman’s',
#   'jekyll',
#   'lanyon',
#   'henry',
#   'jekyll',
#   'jekyll',
#   'jekyll'],
#  'jekyll': ['and',
#   'was',
#   'm.d',
#   'has',
#   'became',
#   'he',
#   'for',
#   'if',
#   'at',
#   'was',
#   'is',
#   'he',
#   'will',
#   'will',
#   'was',
#   'was',
#   'began',
#   'grew',
#   'said',
#   'laying',
#   'is',
#   'who',
#   'looking',
#   'i',
#   'whom',
#   'before',
#   'sir',
#   'forge',
#   'he',
#   'is',
#   'he',
#   'complaining',
#   'wrote',
#   'utterson',
#   'bracketted',
#   'and',
#   'what',
#   'he',
#   'come',
#   'to',
#   'presents',
#   'god',
#   'and',
#   'utterson',
#   'cried',
#   'dead',
#   'had',
#   'he',
#   'want',
#   'there',
#   'i',
#   'my',
#   'upon',
#   'i',
#   'on',
#   'what',
#   'even',
#   'that',
#   'that',
#   'i',
#   'the',
#   'stood',
#   'was',
#   'but',
#   'as',
#   'i',
#   'had',
#   'it',
#   'who',
#   'or',
#   'had',
#   'was',
#   'would',
#   'with',
#   'was',
#   'perhaps',
#   'then',
#   'at',
#   'and',
#   'it',
#   'was',
#   'was',
#   'can',
#   'to'],
#  'and': ['mr',
#   'embarrassed',
#   'yet',
#   'when',
#   'loudly',
#   'though',
#   'in',
#   'the',
#   'to',
#   'even',
#   'that',
#   'would',
#   'not',
#   'what',
#   'all',
#   'laying',
#   'lay',
#   'with',
#   'general',
#   'gaiety',
#   'pleased',
#   'just',
#   'a',
#   'bore',
#   'sordid',
#   'distained',
#   'struck',
#   'for',
#   'the',
#   'pointed',
#   'when',
#   'what',
#   'my',
#   'all',
#   'all',
#   'listens',
#   'begins',
#   'the',
#   'then',
#   'left',
#   'brought',
#   'made',
#   'pretty',
#   'there',
#   'dry',
#   'colour',
#   'about',
#   'white',
#   'killing',
#   'would',
#   'all',
#   'there',
#   'at',
#   'where',
#   'presently',
#   'a',
#   'signed',
#   'often',
#   'that',
#   'come',
#   'sneering',
#   'cash',
#   'the',
#   'our',
#   'myself',
#   'passed',
#   'next',
#   'said',
#   'the',
#   'what',
#   'with',
#   'you',
#   'you',
#   'it’s',
#   'away',
#   'presently',
#   'the',
#   'nobody',
#   'then',
#   'yet',
#   'another',
#   'then',
#   'yet',
#   'yet',
#   'it’s',
#   'obviously',
#   'what’s',
#   'the',
#   'sat',
#   'gratefully',
#   'went',
#   'sat',
#   'benefactor',
#   'free',
#   'as',
#   'customary',
#   'hitherto',
#   'out',
#   'now',
#   'set',
#   'received',
#   'welcomed',
#   'a',
#   'decided',
#   'welcomed',
#   'college',
#   'of',
#   'what',
#   'i',
#   'what',
#   'though',
#   'i',
#   'pythias',
#   'being',
#   'then',
#   'fro',
#   'besieged',
#   'still',
#   'as',
#   'tossed',
#   'the',
#   'then',
#   'that',
#   'passed',
#   'smiling',
#   'then',
#   'lo',
#   'even',
#   'do',
#   'if',
#   'still',
#   'at',
#   'leave',
#   'still',
#   'melted',
#   'thus',
#   'grew',
#   'perhaps',
#   'even',
#   'time',
#   'at',
#   'at',
#   'shadow',
#   'in',
#   'the',
#   'clatter',
#   'decisively',
#   'it',
#   'swelled',
#   'very',
#   'the',
#   'as',
#   'touched',
#   'though',
#   'meeting',
#   'then',
#   'then',
#   'the',
#   'à',
#   'he',
#   'only',
#   'now',
#   'the',
#   'disappeared',
#   'putting',
#   'dwarfish',
#   'boldness',
#   'he',
#   'somewhat',
#   'fear',
#   'transfigures',
#   'let',
#   'chambers',
#   'conditions',
#   'the',
#   'at',
#   'comfort',
#   'knocked',
#   'furnished',
#   'he',
#   'leaned',
#   'utterson',
#   'distaste',
#   'in',
#   'the',
#   'goes',
#   'the',
#   'self-love',
#   'the',
#   'raised',
#   'fearful',
#   'then',
#   'the',
#   'all',
#   'mr',
#   'loose-tongued',
#   'strain',
#   'as',
#   'kindness',
#   'warm',
#   'i',
#   'there',
#   'i',
#   'i',
#   'just',
#   'i',
#   'again',
#   'i',
#   'i',
#   'for',
#   'i',
#   'if',
#   'get',
#   'it',
#   'rendered',
#   'startling',
#   'the',
#   'fell',
#   'as',
#   'advancing',
#   'very',
#   'accosted',
#   'the',
#   'old-world',
#   'she',
#   'for',
#   'seemed',
#   'then',
#   'carrying',
#   'a',
#   'at',
#   'clubbed',
#   'next',
#   'hailing',
#   'the',
#   'sounds',
#   'called',
#   'very',
#   'heavy',
#   'one',
#   'gold',
#   'stamped',
#   'which',
#   'address',
#   'he',
#   'been',
#   'with',
#   'drove',
#   'the',
#   'perhaps',
#   'he',
#   'showed',
#   'battered',
#   'particularly',
#   'then',
#   'the',
#   'routing',
#   'hues',
#   'there',
#   'here',
#   'a',
#   'slatternly',
#   'its',
#   'when',
#   'the',
#   'showed',
#   'twopenny',
#   'many',
#   'the',
#   'cut',
#   'silvery-haired',
#   'he',
#   'when',
#   'the',
#   'now',
#   'this',
#   'good',
#   'the',
#   'agreeable',
#   'hurriedly',
#   'on',
#   'as',
#   'get',
#   'the',
#   'that',
#   'carried',
#   'across',
#   'his',
#   'he',
#   'gazed',
#   'now',
#   'silent',
#   'littered',
#   'the',
#   'through',
#   'a',
#   'looking',
#   'there',
#   'bade',
#   'now',
#   'i',
#   'indeed',
#   'for',
#   'i',
#   'yet',
#   'signed',
#   'it',
#   'he',
#   'sleep',
#   'now',
#   'nodded',
#   'he',
#   'had',
#   'only',
#   'if',
#   'handled',
#   'client',
#   'he',
#   'self-reliant',
#   'midway',
#   'through',
#   'smother',
#   'the',
#   'to',
#   'he',
#   'above',
#   'critic',
#   'obliging',
#   'by',
#   'he',
#   'studied',
#   'by',
#   'the',
#   'sedulously',
#   'his',
#   'all',
#   'violent',
#   'gradually',
#   'to',
#   'entertainer',
#   'whilst',
#   'brighten',
#   'for',
#   'the',
#   'again',
#   'saw',
#   'was',
#   'having',
#   'the',
#   'older',
#   'yet',
#   'quality',
#   'yet',
#   'that',
#   'the',
#   'yet',
#   'i',
#   'he',
#   'i',
#   'then',
#   'wrong',
#   'in',
#   'talk',
#   'do',
#   'wrote',
#   'asking',
#   'the',
#   'sometimes',
#   'a',
#   'terrors',
#   'you',
#   'that',
#   'amities',
#   'an',
#   'now',
#   'peace',
#   'the',
#   'unprepared',
#   'words',
#   'in',
#   'sitting',
#   'set',
#   'sealed',
#   'in',
#   'the',
#   'then',
#   'broke',
#   'marked',
#   'the',
#   'horrible',
#   'dive',
#   'faith',
#   'the',
#   'it',
#   'fearful',
#   'surrounded',
#   'sounds',
#   'to',
#   'speak',
#   'that',
#   'shared',
#   'by',
#   'take',
#   'even',
#   'a',
#   'full',
#   'sitting',
#   'me',
#   'take',
#   'mr',
#   'speak',
#   'succeeded',
#   'despair',
#   'they',
#   'left',
#   'it',
#   'looked',
#   'there',
#   'walked',
#   'then',
#   'here',
#   'tell',
#   'how',
#   'i',
#   'i',
#   'except',
#   'his',
#   'rather',
#   'see',
#   'get',
#   'greatcoat',
#   'perhaps',
#   'flying',
#   'lawny',
#   'flecked',
#   'touch',
#   'dust',
#   'the',
#   'in',
#   'mopped',
#   'his',
#   'broken',
#   'god',
#   'a',
#   'about',
#   'women',
#   'the',
#   'now',
#   'indeed',
#   'turned',
#   'now',
#   'we’ll',
#   'then',
#   'led',
#   'i',
#   'see',
#   'followed',
#   'bottles',
#   'listen',
#   'making',
#   'obvious',
#   'knocked',
#   'even',
#   'taking',
#   'into',
#   'the',
#   'who’s',
#   'why',
#   'day',
#   'cannot',
#   'throw',
#   'a',
#   'the',
#   'twice',
#   'thrice',
#   'complaints',
#   'i',
#   'another',
#   'handed',
#   'quite',
#   'should',
#   'then',
#   'he',
#   'then',
#   'there',
#   'whipped',
#   'run',
#   'then',
#   'passed',
#   'deform',
#   'the',
#   'appalling',
#   'natural',
#   'delivers',
#   'there’s',
#   'began',
#   'this',
#   'it',
#   'now',
#   'me',
#   'whatever',
#   'you',
#   'balanced',
#   'i',
#   'the',
#   'it',
#   'then',
#   'thin',
#   'whipped',
#   'i',
#   'i',
#   'nervous',
#   'i',
#   'the',
#   'take',
#   'now',
#   'taking',
#   'it',
#   'draughts',
#   'fro',
#   'fro',
#   'the',
#   'tell',
#   'oddly',
#   'they',
#   'down',
#   'down',
#   'i',
#   'shall',
#   'the',
#   'hinges',
#   'again',
#   'the',
#   'the',
#   'it',
#   'the',
#   'the',
#   'peered',
#   'chattering',
#   'nearer',
#   'but',
#   'still',
#   'beheld',
#   'by',
#   'the',
#   'it',
#   'was',
#   'by',
#   'looked',
#   'with',
#   'a',
#   'all',
#   'he',
#   'lying',
#   'the',
#   'still',
#   'even',
#   'the',
#   'utterson',
#   'their',
#   'fearful',
#   'surely',
#   'then',
#   'bore',
#   'several',
#   'as',
#   'then',
#   'last',
#   'he',
#   'dated',
#   'here',
#   'then',
#   'how',
#   'in',
#   'with',
#   'read',
#   'all',
#   'must',
#   'first',
#   'if',
#   'unhappy',
#   'gave',
#   'read',
#   'utterson',
#   'old',
#   'i',
#   'although',
#   'with',
#   'you',
#   'to',
#   'a',
#   'to',
#   'earned',
#   'that',
#   'my',
#   'yet',
#   'save',
#   'this',
#   'once',
#   'if',
#   'an',
#   'drove',
#   'had',
#   'a',
#   'we',
#   'have',
#   'the',
#   'after',
#   'i',
#   'tied',
#   'returned',
#   'when',
#   'seemed',
#   'some',
#   'contained',
#   'quite',
#   'there',
#   'once',
#   'followed',
#   'the',
#   'even',
#   'though',
#   'found',
#   'when',
#   'at',
#   'made',
#   'as',
#   'great',
#   'last',
#   'was',
#   'merely',
#   'to',
#   'sober',
#   'rolled',
#   'the',
#   'misbegotten',
#   'revolting',
#   'to',
#   'character',
#   'status',
#   'so',
#   'sought',
#   'i',
#   'sat',
#   'with',
#   'the',
#   'my',
#   'i',
#   'put',
#   'i',
#   'some',
#   'still',
#   'then',
#   'laid',
#   'his',
#   'reason',
#   'as',
#   'the',
#   'gave',
#   'added',
#   'to',
#   'at',
#   'the',
#   'then',
#   'looked',
#   'now',
#   'to',
#   'neither',
#   'new',
#   'power',
#   'your',
#   'you',
#   'now',
#   'material',
#   'drank',
#   'held',
#   'as',
#   'the',
#   'alter',
#   'the',
#   'leaped',
#   'o',
#   'again',
#   'shaken',
#   'half',
#   'groping',
#   'my',
#   'yet',
#   'i',
#   'night',
#   'i',
#   'that',
#   'yet',
#   'that',
#   'hunted',
#   'good',
#   'thus',
#   'distinguished',
#   'indeed',
#   'wear',
#   'that',
#   'began',
#   'take',
#   'position',
#   'hid',
#   'with',
#   'ill',
#   'compound',
#   'inveterately',
#   'is',
#   'plunged',
#   'suffering',
#   'it',
#   'the',
#   'shed',
#   'from',
#   'the',
#   'i',
#   'independent',
#   'in',
#   'in',
#   'primitive',
#   'from',
#   'remorse',
#   'the',
#   'securely',
#   'no',
#   'penitence',
#   'pluck',
#   'burthen',
#   'when',
#   'more',
#   'effulgence',
#   'a',
#   'countenance',
#   'bore',
#   'shook',
#   'profound',
#   'late',
#   'smoke',
#   'when',
#   'a',
#   'i',
#   'from',
#   'the',
#   'delighted',
#   'in',
#   'for',
#   'i',
#   'triumph',
#   'coming',
#   'less',
#   'control',
#   'much',
#   'hence',
#   'younger',
#   'plainly',
#   'decay',
#   'yet',
#   'human',
#   'single',
#   'divided',
#   'in',
#   'evil',
#   'edward',
#   'conclusive',
#   'must',
#   'hurrying',
#   'drank',
#   'came',
#   'the',
#   'from',
#   'birth',
#   'like',
#   'swift',
#   'the',
#   'the',
#   'improvement',
#   'as',
#   'i',
#   'highly',
#   'to',
#   'i',
#   'furnished',
#   'engaged',
#   'unscrupulous',
#   'power',
#   'to',
#   'made',
#   'thus',
#   'reputation',
#   'in',
#   'spring',
#   'swallow',
#   'whatever',
#   'there',
#   'sent',
#   'villainous',
#   'thought',
#   'insidiously',
#   'hyde',
#   'thus',
#   'the',
#   'the',
#   'at',
#   'pay',
#   'when',
#   'woke',
#   'tall',
#   'the',
#   'in',
#   'size',
#   'comely',
#   'thickly',
#   'startling',
#   'bounding',
#   'icy',
#   'then',
#   'through',
#   'then',
#   'going',
#   'drew',
#   'in',
#   'ten',
#   'was',
#   'i',
#   'possibilities',
#   'nourished',
#   'i',
#   'the',
#   'once',
#   'these',
#   'in',
#   'better',
#   'becoming',
#   'worse',
#   'shared',
#   'adventures',
#   'had',
#   'aspirations',
#   'to',
#   'forever',
#   'friendless',
#   'commonplace',
#   'alarms',
#   'trembling',
#   'it',
#   'was',
#   'discontented',
#   'cherishing',
#   'bade',
#   'secret',
#   'enjoyed',
#   'longings',
#   'at',
#   'swallowed',
#   'insensate',
#   'that',
#   'in',
#   'raged',
#   'it',
#   'fled',
#   'trembling',
#   'stimulated',
#   'to',
#   'yet',
#   'still',
#   'as',
#   'remorse',
#   'lifted',
#   'through',
#   'again',
#   'prayers',
#   'sounds',
#   'still',
#   'o',
#   'come',
#   'ground',
#   'that',
#   'guarded',
#   'the',
#   'slay',
#   'i',
#   'that',
#   'innocent',
#   'as',
#   'it',
#   'this',
#   'yet',
#   'the',
#   'sweet',
#   'then',
#   'at',
#   'the',
#   'left',
#   'then',
#   'hairy',
#   'now',
#   'my',
#   'thought',
#   'how',
#   'displeasing',
#   'once',
#   'summoning',
#   'the',
#   'brought',
#   'one',
#   'that',
#   'thence',
#   'was',
#   'fro',
#   'hatred',
#   'when',
#   'ventured',
#   'she',
#   'got',
#   'profound',
#   'feared',
#   'i',
#   'close',
#   'gratitude',
#   'i',
#   'freezing',
#   'alas',
#   'the',
#   'only',
#   'night',
#   'by',
#   'emptied',
#   'mind',
#   'solely',
#   'a',
#   'certainly',
#   'was',
#   'beyond',
#   'voices',
#   'sinned',
#   'had',
#   'this',
#   'felt',
#   'at',
#   'in',
#   'deposed',
#   'return',
#   'he',
#   'destroying',
#   'indeed',
#   'freeze',
#   'passion',
#   'when',
#   'the',
#   'yet',
#   'my',
#   'which',
#   'nature',
#   'mixed',
#   'the',
#   'it',
#   'i',
#   'that',
#   'i',
#   'great',
#   'circumscription',
#   'indeed',
#   'crushed',
#   'forever',
#   'weeping',
#   'fearstruck',
#   'down',
#   'give',
#   'what',
#   'proceed'],
#  'mr': ['hyde',
#   'hyde',
#   'utterson',
#   'utterson',
#   'richard',
#   'enfield',
#   'utterson',
#   'enfield',
#   'utterson',
#   'enfield',
#   'utterson',
#   'enfield',
#   'utterson',
#   'enfield',
#   'utterson',
#   'enfield',
#   'utterson',
#   'utterson',
#   'utterson',
#   'hyde',
#   'utterson',
#   'utterson',
#   'hyde',
#   'utterson',
#   'utterson',
#   'utterson’s',
#   'enfield’s',
#   'hyde',
#   'utterson',
#   'hyde',
#   'seek',
#   'utterson',
#   'utterson',
#   'hyde',
#   'hyde',
#   'utterson',
#   'hyde',
#   'utterson',
#   'hyde',
#   'utterson',
#   'hyde',
#   'utterson',
#   'utterson',
#   'hyde',
#   'hyde',
#   'utterson',
#   'hyde',
#   'hyde',
#   'utterson',
#   'utterson',
#   'utterson',
#   'hyde',
#   'utterson',
#   'hyde',
#   'hyde',
#   'utterson',
#   'utterson',
#   'utterson',
#   'hyde',
#   'hyde',
#   'hyde',
#   'utterson',
#   'utterson',
#   'hyde',
#   'utterson',
#   'utterson',
#   'hyde’s',
#   'utterson',
#   'hyde',
#   'utterson',
#   'hyde',
#   'utterson',
#   'utterson',
#   'utterson',
#   'guest',
#   'guest',
#   'hyde’s',
#   'utterson',
#   'utterson',
#   'utterson',
#   'utterson',
#   'hyde',
#   'utterson',
#   'hyde',
#   'utterson',
#   'utterson',
#   'enfield',
#   'hyde',
#   'enfield',
#   'enfield',
#   'enfield',
#   'utterson',
#   'utterson',
#   'enfield',
#   'utterson',
#   'utterson',
#   'utterson',
#   'utterson’s',
#   'utterson',
#   'utterson',
#   'utterson',
#   'utterson',
#   'utterson’s',
#   'utterson',
#   'utterson',
#   'utterson',
#   'utterson',
#   'utterson',
#   'utterson',
#   'utterson',
#   'utterson',
#   'utterson',
#   'utterson',
#   'utterson',
#   'hyde',
#   'utterson',
#   'hyde',
#   'utterson',
#   'utterson',
#   'hyde',
#   'utterson',
#   'utterson',
#   'hyde',
#   'hyde'],
#  'hyde': ['by',
#   'dr',
#   'hm',
#   'that',
#   'but',
#   'should',
#   'that',
#   'he',
#   'repeated',
#   'if',
#   'he',
#   'i',
#   'shrank',
#   'blowing',
#   'appeared',
#   'it',
#   'a',
#   'with',
#   'had',
#   'was',
#   'sat',
#   'go',
#   'has',
#   'asked',
#   'if',
#   'suspects',
#   'the',
#   'i',
#   'i',
#   'who',
#   'broke',
#   'but',
#   'a',
#   'had',
#   'had',
#   'i',
#   'and',
#   'who',
#   'had',
#   'now',
#   'had',
#   'it',
#   'i',
#   'why',
#   'yes',
#   'ay',
#   'he',
#   'is',
#   'the',
#   'and',
#   'i',
#   'was',
#   'none',
#   'alone',
#   'hence',
#   'i',
#   'was',
#   'whom',
#   'without',
#   'would',
#   'they',
#   'but',
#   'after',
#   'alone',
#   'and',
#   'had',
#   'himself',
#   'i',
#   'i',
#   'how',
#   'at',
#   'had',
#   'become',
#   'but',
#   'was',
#   'had',
#   'was',
#   'would',
#   'i',
#   'which',
#   'struggling',
#   'yet',
#   'had',
#   'was',
#   'was',
#   'peep',
#   'the',
#   'a',
#   'rose',
#   'in',
#   'that',
#   'it',
#   'that',
#   'seemed',
#   'for',
#   'for',
#   'will',
#   'die'],
#  'by': ['robert',
#   'a',
#   'those',
#   'these',
#   'the',
#   'mr',
#   'the',
#   'a',
#   'questions',
#   'before',
#   'his',
#   'which',
#   'all',
#   'any',
#   'ten',
#   'a',
#   'description',
#   'a',
#   'the',
#   'the',
#   'the',
#   'the',
#   'chance',
#   'the',
#   'the',
#   'a',
#   'the',
#   'excellent',
#   'his',
#   'my',
#   'talking',
#   'a',
#   'the',
#   'the',
#   'the',
#   'this',
#   'hypocrisy',
#   'poole',
#   'the',
#   'three',
#   'it',
#   'the',
#   'post',
#   'that',
#   'the',
#   'habit',
#   'that',
#   'all',
#   'the',
#   'the',
#   'the',
#   'the',
#   'the',
#   'little',
#   'the',
#   'an',
#   'his',
#   'any',
#   'means',
#   'this',
#   'the',
#   'the',
#   'the',
#   'fair',
#   'foul',
#   'brute',
#   'their',
#   'the',
#   'the',
#   'the',
#   'a',
#   'the',
#   'the',
#   'on',
#   'the',
#   'this',
#   'no',
#   'its',
#   'the',
#   'the',
#   'several',
#   'me',
#   'a',
#   'his',
#   'a',
#   'a',
#   'me',
#   'the',
#   'nature',
#   'whose',
#   'the',
#   'which',
#   'the',
#   'theory',
#   'ambition',
#   'the',
#   'the',
#   'hyde',
#   'opening',
#   'sloping',
#   'friends',
#   'the',
#   'these',
#   'which',
#   'a',
#   'a',
#   'which',
#   'the',
#   'the',
#   'his',
#   'a',
#   'the',
#   'fever',
#   'one',
#   'suicide',
#   'a',
#   'his'],
#  'robert': ['louis'],
#  'louis': ['stevenson'],
#  'stevenson': ['contents'],
#  'contents': ['story',
#   'the',
#   'thank',
#   'i',
#   'ran',
#   'of',
#   'increased',
#   'as',
#   'some',
#   'the',
#   'he'],
#  'story': ['of', 'of', 'indeed', 'but', 'for', 'of', 'that'],
#  'door': ['search',
#   'mr',
#   'on',
#   'which',
#   'he',
#   'whipped',
#   'at',
#   'in',
#   'said',
#   'and',
#   'to',
#   'of',
#   'in',
#   'crossing',
#   'and',
#   'of',
#   'is',
#   'she',
#   'and',
#   'where',
#   'covered',
#   'possibly',
#   'was',
#   'is',
#   'of',
#   'both',
#   'was',
#   'the',
#   'with',
#   'mr',
#   'and',
#   'was',
#   'where',
#   'ah',
#   'you',
#   'we',
#   'poole',
#   'leaped',
#   'fell',
#   'on',
#   'they',
#   'in',
#   'of',
#   'and',
#   'of',
#   'was',
#   'stood',
#   'i',
#   'give',
#   'and',
#   'by',
#   'i'],
#  'search': ['for', 'for', 'with', 'by'],
#  'for': ['mr',
#   'vintages',
#   'twenty',
#   'others',
#   'he',
#   'many',
#   'all',
#   'close',
#   'a',
#   'the',
#   'the',
#   'whom',
#   'they',
#   'the',
#   'the',
#   'more',
#   'close',
#   'my',
#   'some',
#   'myself',
#   'the',
#   'a',
#   'all',
#   'i',
#   'mr',
#   'mr',
#   'any',
#   'these',
#   'me',
#   'old',
#   'his',
#   'the',
#   'the',
#   'a',
#   'instance',
#   'it',
#   'o',
#   'the',
#   'the',
#   'if',
#   'once',
#   'solitude',
#   'mr',
#   'all',
#   'the',
#   'him',
#   'justice',
#   'my',
#   'she',
#   'whom',
#   'the',
#   'one',
#   'here',
#   'a',
#   'the',
#   'instance',
#   'the',
#   'him',
#   'mr',
#   'even',
#   'your',
#   'certainty',
#   'a',
#   'his',
#   'and',
#   'some',
#   'me',
#   'a',
#   'advice',
#   'presently',
#   'i',
#   'a',
#   'the',
#   'by',
#   'dr',
#   'charities',
#   'religion',
#   'more',
#   'the',
#   'god’s',
#   'i',
#   'sufferings',
#   'it',
#   'the',
#   'a',
#   'the',
#   'you',
#   'about',
#   'the',
#   'the',
#   'yourself',
#   'mr',
#   'struggle',
#   'all',
#   'his',
#   'look',
#   'some',
#   'have',
#   'his',
#   'god’s',
#   'this',
#   'the',
#   'one',
#   'aught',
#   'yourself',
#   'that',
#   'what',
#   'all',
#   'god’s',
#   'tea',
#   'the',
#   'him',
#   'us',
#   'all',
#   'years',
#   'an',
#   'which',
#   'what',
#   'it',
#   'the',
#   'we',
#   'this',
#   'something',
#   'yourself',
#   'to-night',
#   'consultation',
#   'the',
#   'what',
#   'you',
#   'a',
#   'him',
#   'his',
#   'it',
#   'there',
#   'the',
#   'in',
#   'a',
#   'my',
#   'two',
#   'ever',
#   'any',
#   'the',
#   'the',
#   'the',
#   'his',
#   'me',
#   'even',
#   'my',
#   'one',
#   'near',
#   'while',
#   'any',
#   'i',
#   'two',
#   'two',
#   'the',
#   'the',
#   'others',
#   'myself',
#   'licence',
#   'me',
#   'him',
#   'myself',
#   'in',
#   'observation',
#   'my',
#   'a',
#   'the',
#   'all',
#   'jekyll',
#   'his',
#   'years',
#   'the',
#   'a',
#   'if'],
#  'was': ['quite',
#   'a',
#   'never',
#   'to',
#   'austere',
#   'alone',
#   'frequently',
#   'easy',
#   'undemonstrative',
#   'the',
#   'a',
#   'reported',
#   'small',
#   'broken',
#   'two',
#   'equipped',
#   'blistered',
#   'that',
#   'this',
#   'coming',
#   'literally',
#   'stumping',
#   'running',
#   'able',
#   'hellish',
#   'like',
#   'already',
#   'perfectly',
#   'not',
#   'one',
#   'only',
#   'what',
#   'the',
#   'like',
#   'in',
#   'in',
#   'the',
#   'something',
#   'to',
#   'a',
#   'stiff',
#   'good',
#   'only',
#   'quite',
#   'a',
#   'genuine',
#   'a',
#   'recalled',
#   'the',
#   'a',
#   'his',
#   'over',
#   'taken',
#   'holograph',
#   'made',
#   'the',
#   'his',
#   'his',
#   'already',
#   'but',
#   'worse',
#   'madness',
#   'subjected',
#   'a',
#   'the',
#   'somewhat',
#   'the',
#   'somewhat',
#   'the',
#   'a',
#   'so',
#   'digging',
#   'engaged',
#   'given',
#   'but',
#   'that',
#   'the',
#   'without',
#   'plenty',
#   'to',
#   'rewarded',
#   'a',
#   'very',
#   'aware',
#   'with',
#   'small',
#   'only',
#   'the',
#   'thus',
#   'one',
#   'pale',
#   'a',
#   'still',
#   'now',
#   'now',
#   'a',
#   'wont',
#   'a',
#   'rare',
#   'ashamed',
#   'gone',
#   'wild',
#   'young',
#   'fairly',
#   'humbled',
#   'quite',
#   'no',
#   'liked',
#   'liked',
#   'no',
#   'distasteful',
#   'never',
#   'abominable',
#   'rude',
#   'startled',
#   'cloudless',
#   'brilliantly',
#   'romantically',
#   'just',
#   'pleased',
#   'surprised',
#   'trifling',
#   'trampling',
#   'two',
#   'gone',
#   'of',
#   'brought',
#   'out',
#   'laid',
#   'he',
#   'by',
#   'continually',
#   'conscious',
#   'the',
#   'heir',
#   'mr',
#   'not',
#   'nothing',
#   'often',
#   'nearly',
#   'impossible',
#   'filled',
#   'of',
#   'much',
#   'found',
#   'not',
#   'the',
#   'late',
#   'at',
#   'indifferently',
#   'the',
#   'at',
#   'a',
#   'set',
#   'my',
#   'thinking',
#   'surprised',
#   'written',
#   'about',
#   'handed',
#   'the',
#   'hyde',
#   'a',
#   'the',
#   'positive',
#   'the',
#   'at',
#   'by',
#   'not',
#   'still',
#   'gay',
#   'ready',
#   'no',
#   'not',
#   'it',
#   'a',
#   'mad',
#   'a',
#   'mr',
#   'resented',
#   'unearthed',
#   'simply',
#   'to',
#   'now',
#   'busy',
#   'much',
#   'at',
#   'shut',
#   'confined',
#   'again',
#   'not',
#   'shocked',
#   'visibly',
#   'not',
#   'unlikely',
#   'what',
#   'tempted',
#   'with',
#   'the',
#   'incurable',
#   'amazed',
#   'dead',
#   'emphatically',
#   'another',
#   'disappearance',
#   'set',
#   'perhaps',
#   'out',
#   'on',
#   'impossible',
#   'a',
#   'partly',
#   'very',
#   'still',
#   'half-way',
#   'about',
#   'struck',
#   'instantly',
#   'not',
#   'an',
#   'sitting',
#   'surprised',
#   'altered',
#   'the',
#   'to',
#   'still',
#   'a',
#   'borne',
#   'full',
#   'white',
#   'opened',
#   'brightly',
#   'built',
#   'to',
#   'out',
#   'that',
#   'made',
#   'sometimes',
#   'looking',
#   'not',
#   'main',
#   'this',
#   'open',
#   'at',
#   'but',
#   'my',
#   'my',
#   'not',
#   'more',
#   'never',
#   'but',
#   'never',
#   'murder',
#   'the',
#   'so',
#   'the',
#   'it',
#   'you',
#   'much',
#   'something',
#   'mr',
#   'sure',
#   'now',
#   'only',
#   'different',
#   'set',
#   'still',
#   'tough',
#   'not',
#   'dressed',
#   'quite',
#   'looking',
#   'occupied',
#   'lighted',
#   'filled',
#   'jekyll’s',
#   'there',
#   'locked',
#   'always',
#   'drawn',
#   'amazed',
#   'so',
#   'uppermost',
#   'a',
#   'a',
#   'alive',
#   'to',
#   'a',
#   'now',
#   'a',
#   'never',
#   'insane',
#   'proved',
#   'in',
#   'awaiting',
#   'very',
#   'near',
#   'a',
#   'unlocked',
#   'plain',
#   'highly',
#   'an',
#   'appended',
#   'definite',
#   'this',
#   'dealing',
#   'a',
#   'certain',
#   'small',
#   'struck',
#   'accompanied',
#   'dressed',
#   'far',
#   'something',
#   'added',
#   'indeed',
#   'his',
#   'wrestling',
#   'so',
#   'already',
#   'at',
#   'far',
#   'on',
#   'born',
#   'a',
#   'guilty',
#   'thus',
#   'and',
#   'driven',
#   'in',
#   'no',
#   'on',
#   'only',
#   'radically',
#   'unbearable',
#   'the',
#   'so',
#   'something',
#   'conscious',
#   'suddenly',
#   'no',
#   'brought',
#   'far',
#   'was',
#   'nearly',
#   'with',
#   'less',
#   'so',
#   'written',
#   'conscious',
#   'myself',
#   'doubtless',
#   'because',
#   'pure',
#   'no',
#   'neither',
#   'alert',
#   'projected',
#   'edward',
#   'wholly',
#   'still',
#   'thus',
#   'not',
#   'daily',
#   'on',
#   'tracked',
#   'to',
#   'the',
#   'the',
#   'complete',
#   'often',
#   'a',
#   'apart',
#   'hyde',
#   'guilty',
#   'no',
#   'possible',
#   'easily',
#   'in',
#   'not',
#   'that',
#   'accustomed',
#   'still',
#   'professional',
#   'large',
#   'lean',
#   'the',
#   'in',
#   'changed',
#   'this',
#   'it',
#   'well',
#   'then',
#   'that',
#   'unable',
#   'able',
#   'sitting',
#   'my',
#   'led',
#   'slowly',
#   'composite',
#   'indifferent',
#   'to',
#   'to',
#   'still',
#   'found',
#   'true',
#   'by',
#   'punished',
#   'conscious',
#   'to',
#   'not',
#   'suddenly',
#   'rent',
#   'succeeded',
#   'solved',
#   'thenceforth',
#   'now',
#   'patent',
#   'a',
#   'not',
#   'glad',
#   'glad',
#   'now',
#   'fruitful',
#   'done',
#   'still',
#   'in',
#   'once',
#   'as',
#   'not',
#   'a',
#   'full',
#   'like',
#   'corded',
#   'once',
#   'the',
#   'i',
#   'the',
#   'he',
#   'i',
#   'indeed',
#   'a',
#   'astute',
#   'fully',
#   'driven',
#   'at',
#   'no',
#   'the',
#   'partly',
#   'once',
#   'stepping',
#   'seized',
#   'once',
#   'able',
#   'always',
#   'equal',
#   'a',
#   'co-heir',
#   'the',
#   'dead',
#   'knit',
#   'of',
#   'now',
#   'himself',
#   'without',
#   'in',
#   'impure',
#   'that'],
#  'quite': ['at',
#   'a',
#   'easy',
#   'right',
#   'at',
#   'broken',
#   'safe',
#   'sure',
#   'done',
#   'in',
#   'done',
#   'impossible',
#   'useless',
#   'so',
#   'dark',
#   'gone',
#   'abruptly'],
#  'at': ['ease',
#   'the',
#   'friendly',
#   'the',
#   'the',
#   'that',
#   'the',
#   'last',
#   'once',
#   'a',
#   'the',
#   'first',
#   'my',
#   'last',
#   'least',
#   'four',
#   'rest',
#   'last',
#   'sight',
#   'school',
#   'the',
#   'his',
#   'that',
#   'any',
#   'every',
#   'least',
#   'noon',
#   'night',
#   'all',
#   'last',
#   'his',
#   'that',
#   'each',
#   'the',
#   'home',
#   'ease',
#   'what',
#   'rest',
#   'last',
#   'peace',
#   'first',
#   'that',
#   'the',
#   'the',
#   'the',
#   'times',
#   'home',
#   'this',
#   'the',
#   'once',
#   'the',
#   'the',
#   'last',
#   'an',
#   'a',
#   'his',
#   'last',
#   'least',
#   'a',
#   'the',
#   'once',
#   'last',
#   'once',
#   'quiet',
#   'peace',
#   'the',
#   'least',
#   'the',
#   'that',
#   'which',
#   'once',
#   'the',
#   'an',
#   'least',
#   'the',
#   'last',
#   'his',
#   'him',
#   'the',
#   'once',
#   'this',
#   'once',
#   'maw’s',
#   'the',
#   'the',
#   'the',
#   'the',
#   'his',
#   'hand',
#   'one',
#   'each',
#   'the',
#   'one',
#   'the',
#   'poole',
#   'the',
#   'the',
#   'the',
#   'least',
#   'times',
#   'least',
#   'your',
#   'the',
#   'once',
#   'midnight',
#   'the',
#   'this',
#   'midnight',
#   'once',
#   'the',
#   'the',
#   'the',
#   'last',
#   'the',
#   'the',
#   'his',
#   'the',
#   'sight',
#   'first',
#   'the',
#   'one',
#   'the',
#   'it',
#   'all',
#   'the',
#   'the',
#   'the',
#   'last',
#   'once',
#   'the',
#   'the',
#   'that',
#   'first',
#   'the',
#   'that',
#   'that',
#   'times',
#   'once',
#   'the',
#   'the',
#   'home',
#   'suspicion',
#   'my',
#   'times',
#   'which',
#   'last',
#   'another',
#   'a',
#   'the',
#   'seeing',
#   'such',
#   'a',
#   'last',
#   'last',
#   'least',
#   'once',
#   'the',
#   'last',
#   'last',
#   'the',
#   'home',
#   'my',
#   'the',
#   'last',
#   'lanyon’s',
#   'least',
#   'home',
#   'all',
#   'every',
#   'the',
#   'the'],
#  'ease': ['the', 'to', 'a'],
#  'carew': ['murder', 'murder', 'good', 'was', 'hastie'],
#  'murder': ['case',
#   'case',
#   'you',
#   'of',
#   'he',
#   'done',
#   'he',
#   'of',
#   'had',
#   'lusting'],
#  'incident': ['of', 'of', 'at', 'of', 'of', 'at', 'this'],
#  'letter': ['incident',
#   'it',
#   'and',
#   'the',
#   'was',
#   'well',
#   'handed',
#   'had',
#   'which',
#   'had',
#   'ran',
#   'in',
#   'e',
#   'not',
#   'i',
#   'of'],
#  'lanyon': ['incident',
#   'had',
#   'he',
#   'sat',
#   'said',
#   'but',
#   'no',
#   'at',
#   'you',
#   'time',
#   'had',
#   'declared',
#   'we',
#   'ask',
#   'and',
#   'was',
#   'took',
#   'what',
#   'warned',
#   'you',
#   'my',
#   'and',
#   'do',
#   'he',
#   'you',
#   'henry',
#   'how',
#   'and'],
#  'window': ['the', 'nothing', 'overlooked', 'and', 'it', 'was'],
#  'last': ['night',
#   'reputable',
#   'good',
#   'i',
#   'he',
#   'you',
#   'my',
#   'his',
#   'i',
#   'getting',
#   'time',
#   'however',
#   'received',
#   'let',
#   'returning',
#   'two',
#   'long',
#   'turned',
#   'night',
#   'week',
#   'sample',
#   'of',
#   'of',
#   'was',
#   'i',
#   'but',
#   'overcame',
#   'ingredient',
#   'in',
#   'to',
#   'in',
#   'months',
#   'year',
#   'fell',
#   'and',
#   'thinking',
#   'calamity',
#   'of',
#   'time',
#   'earthly',
#   'moment'],
#  'night': ['dr',
#   'in',
#   'however',
#   'of',
#   'and',
#   'and',
#   'under',
#   'frost',
#   'was',
#   'very',
#   'than',
#   'he',
#   'after',
#   'mr',
#   'of',
#   'and',
#   'only',
#   'jekyll',
#   'in',
#   'before',
# ...
#  'scarcely': ['a'],
#  'great': ['while',
#   'dr',
#   'dark',
#   'field',
#   'way',
#   'air',
#   'deal',
#   'interest',
#   'a',
#   'interest',
#   'importance',
#   'flame',
#   'chocolate-coloured',
#   'a',
#   'arteries',
#   'student',
#   'deal',
#   'firmness',
#   'and',
#   'curiosity',
#   'pleasure',
#   'and',
#   'kitchen',
#   'esteem',
#   'trouble',
#   'muscular',
#   'apparent',
#   'a',
#   'sickness',
#   'effort',
#   'effort',
#   'prudence',
#   'good'],
#  'while': ['the',
#   'in',
#   'he',
#   'ago',
#   'in',
#   'i',
#   'he',
#   'we',
#   'under',
#   'their',
#   'jekyll'],
#  'adventure': ['there'],
#  'are': ['three',
#   'always',
#   'so',
#   'sure',
#   'and',
#   'going',
#   'they',
#   'it',
#   'unfortunate',
#   'perfectly',
#   'you',
#   'in',
#   'counted',
#   'three',
#   'better',
#   'very',
#   'that',
#   'you',
#   'and',
#   'you',
#   'a',
#   'all',
#   'no',
#   'about',
#   'going',
#   'broad',
#   'aroused',
#   'rusty',
#   'one',
#   'all',
#   'to',
#   'in',
#   'of',
#   'doubtless',
#   'you',
#   'numbered',
#   'commingled',
#   'as'],
#  'windows': ['looking', 'are', 'barred', 'and', 'to', 'was'],
#  'looking': ['on',
#   'man',
#   'forth',
#   'up',
#   'in',
#   'out',
#   'deathly',
#   'mr',
#   'well',
#   'up',
#   'on',
#   'sadly'],
#  'floor': ['none', 'the', 'with', 'strewn', 'i', 'sir', 'so', 'the', 'behind'],
#  'none': ['below', 'stranger', 'the', 'could'],
#  'below': ['the', 'they', 'his'],
#  'always': ['shut',
#   'follow',
#   'mean',
#   'sure',
#   'been',
#   'bringing',
#   'standing',
#   'equally',
#   'as'],
#  'shut': ['but', 'his', 'against', 'even', 'up', 'and', 'on'],
#  'they’re': ['clean', 'all'],
#  'clean': ['and', 'as', 'breast', 'breast'],
#  'chimney': ['which', 'shelf'],
#  'generally': ['smoking'],
#  'smoking': ['so'],
#  'somebody': ['must'],
#  'must': ['live',
#   'be',
#   'seem',
#   'be',
#   'rise',
#   'have',
#   'be',
#   'be',
#   'have',
#   'put',
#   'have',
#   'be',
#   'know',
#   'never',
#   'not',
#   'you',
#   'suffer',
#   'lie',
#   'have',
#   'know',
#   'know',
#   'go',
#   'and',
#   'be',
#   'have',
#   'be',
#   'have',
#   'be',
#   'be',
#   'go',
#   'appear',
#   'die',
#   'here',
#   'still',
#   'flee',
#   'have',
#   'have',
#   'have',
#   'employ',
#   'follow',
#   'i'],
#  'live': ['there', 'to'],
#  'sure': ['for',
#   'he',
#   'but',
#   'you’ll',
#   'of',
#   'of',
#   'i',
#   'dependence',
#   'that',
#   'to',
#   'and',
#   'my',
#   'destroyed'],
#  'buildings': ['are'],
#  'packed': ['together'],
#  'together': ['about', 'could', 'like', 'and', 'bradshaw', 'that', 'in'],
#  'ends': ['and'],
#  'pair': ['walked', 'stared', 'of'],
#  'walked': ['on', 'over', 'some', 'was', 'on', 'with', 'fast'],
#  'again': ['for',
#   'walked',
#   'with',
#   'said',
#   'into',
#   'continued',
#   'and',
#   'and',
#   'upon',
#   'in',
#   'i',
#   'on',
#   'and',
#   'refused',
#   'as',
#   'were',
#   'through',
#   'in',
#   'a',
#   'and',
#   'the',
#   'more',
#   'and',
#   'for',
#   'in',
#   'to',
#   'compounded',
#   'and',
#   'with',
#   'with',
#   'raging',
#   'that',
#   'from',
#   'and'],
#  'silence': ['and',
#   'and',
#   'after',
#   'utterson',
#   'too',
#   'the',
#   'followed',
#   'and'],
#  'that’s': ['a', 'it', 'talking', 'very', 'not', 'such', 'not'],
#  'yours': ['yes', 'a'],
#  'there’s': ['one', 'a', 'been', 'the', 'a', 'blood'],
#  'want': ['to',
#   'to',
#   'of',
#   'i',
#   'to',
#   'my',
#   'to',
#   'you',
#   'you',
#   'you',
#   'with',
#   'you'],
#  'harm': ['it'],
#  'hm': ['said'],
#  'sort': ['of', 'of', 'of', 'of', 'that'],
#  'describe': ['there', 'him', 'him', 'said', 'as'],
#  'wrong': ['with', 'wrong', 'in', 'of', 'take', 'amen'],
#  'displeasing': ['something', 'smile', 'visitor'],
#  'down-right': ['detestable'],
#  'detestable': ['i', 'attributes'],
#  'disliked': ['and'],
#  'scarce': ['know', 'at', 'have', 'read', 'know', 'rung', 'use', 'grant'],
#  'why': ['he',
#   'money’s',
#   'do',
#   'did',
#   'then',
#   'it',
#   'had',
#   'did',
#   'you',
#   'yes',
#   'fled',
#   'don’t',
#   'could',
#   'was'],
#  'deformed': ['somewhere'],
#  'somewhere': ['he'],
#  'gives': ['a'],
#  'feeling': ['of', 'for', 'returned', 'of'],
#  'deformity': ['although', 'without', 'with', 'and', 'of'],
#  'although': ['i', 'a', 'it', 'the', 'we', 'they', 'i'],
#  'couldn’t': ['specify'],
#  'specify': ['the'],
#  'he’s': ['an', 'a', 'shut'],
#  'extraordinary': ['looking', 'quickness'],
#  'can': ['name',
#   'make',
#   'see',
#   'he',
#   'it',
#   'make',
#   'get',
#   'be',
#   'help',
#   'take',
#   'bear',
#   'be',
#   'sit',
#   'do',
#   'do',
#   'bear',
#   'bear',
#   'i',
#   'hardly',
#   'tell',
#   'we',
#   'neither',
#   'exaggerate',
#   'only',
#   'bring',
#   'scarce',
#   'say',
#   'i',
#   'think'],
#  'memory': ['for', 'he', 'has', 'lest', 'dwell', 'in', 'swarmed', 'the'],
#  'declare': ['i', 'it', 'this', 'at'],
#  'moment': ['mr',
#   'with',
#   'i',
#   'with',
#   'his',
#   'the',
#   'the',
#   'however',
#   'with',
#   'i',
#   'friendship',
#   'when',
#   'but',
#   'of',
#   'and',
#   'in',
#   'the',
#   'i',
#   'of',
#   'braced',
#   'at',
#   'like',
#   'of',
#   'before',
#   'my',
#   'in',
#   'will',
#   'god'],
#  'obviously': ['under'],
#  'under': ['a',
#   'the',
#   'the',
#   'the',
#   'foot',
#   'which',
#   'the',
#   'these',
#   'no',
#   'his',
#   'a',
#   'what',
#   'a',
#   'control',
#   'the',
#   'the',
#   'shelter',
#   'my',
#   'foot',
#   'the',
#   'the',
#   'the'],
#  'weight': ['of', 'off'],
#  'consideration': ['you', 'the', 'in'],
#  'inquired': ['at', 'particularly', 'the', 'suddenly', 'we'],
#  'dear': ['sir', 'no', 'utterson', 'lanyon', 'lanyon', 'lanyon'],
#  'began': ['enfield',
#   'to',
#   'to',
#   'to',
#   'to',
#   'slowly',
#   'the',
#   'to',
#   'to',
#   'to',
#   'to',
#   'for',
#   'to',
#   'in',
#   'to',
#   'to',
#   'to',
#   'swiftly',
#   'to',
#   'to',
#   'lazily',
#   'to',
#   'to',
#   'at',
#   'to',
#   'to',
#   'to',
#   'to',
#   'to',
#   'to'],
#  'surprised': ['out', 'to', 'and', 'at', 'at', 'nor', 'to', 'by'],
#  'seem': ['strange', 'as', 'a', 'pretty'],
#  'fact': ['is'],
#  'party': ['it', 'lanyon'],
#  'because': ['i', 'it', 'i', 'an', 'the', 'i', 'i', 'as', 'they', 'all'],
#  'tale': ['has', 'went', 'poole', 'my'],
#  'has': ['gone',
#   'it',
#   'i',
#   'a',
#   'forgotten',
#   'he',
#   'rather',
#   'elicited',
#   'been',
#   'been',
#   'his',
#   'seen',
#   'been',
#   'not',
#   'fled',
#   'his',
#   'shown',
#   'the',
#   'faded',
#   'left',
#   'made',
#   'ever',
#   'ever',
#   'now',
#   'finally',
#   'passed',
#   'hitherto',
#   'been',
#   'already'],
#  'gone': ['home',
#   'out',
#   'upstairs',
#   'long',
#   'away',
#   'and',
#   'to',
#   'too',
#   'into',
#   'to',
#   'and',
#   'on'],
#  'inexact': ['in'],
#  'correct': ['it'],
#  'warned': ['me', 'me'],
#  'touch': ['of', 'of', 'his', 'of'],
#  'sullenness': ['but'],
#  'pedantically': ['exact'],
#  'exact': ['as'],
#  'what’s': ['more'],
#  'use': ['it', 'observed', 'echoed', 'a', 'was'],
#  'ago': ['mr',
#   'to',
#   'but',
#   'resolved',
#   'the',
#   'restored',
#   'when',
#   'i',
#   'and',
#   'have'],
#  'sighed': ['deeply', 'the', 'is'],
#  'deeply': ['but', 'and', 'than', 'into'],
#  'word': ['and',
#   'utterson',
#   'and',
#   'said',
#   'more',
#   'or',
#   'in',
#   'with',
#   'double'],
#  'young': ['man', 'man', 'a', 'hyde', 'man'],
#  'resumed': ['here', 'the', 'the', 'utterson', 'if'],
#  'here': ['is',
#   'by',
#   'thank',
#   'replied',
#   'utterson',
#   'it',
#   'for',
#   'in',
#   'again',
#   'again',
#   'and',
#   'he',
#   'is',
#   'we',
#   'said',
#   'sir',
#   'poole',
#   'with',
#   'he',
#   'and',
#   'he',
#   'this',
#   'sir',
#   'i',
#   'and',
#   'were',
#   'at',
#   'at',
#   'i',
#   'in',
#   'speak',
#   'then'],
#  'lesson': ['to', 'o', 'i'],
#  'ashamed': ['of', 'of'],
#  'tongue': ['let', 'poole'],
#  'bargain': ['never', 'might'],
#  'refer': ['to'],
#  'heart': ['said',
#   'poor',
#   'at',
#   'he',
#   'that',
#   'in',
#   'that',
#   'sinks',
#   'i',
#   'by',
#   'to'],
#  'shake': ['hands', 'me', 'and'],
#  'evening': ['mr', 'and', 'after', 'delivery', 'i'],
#  'bachelor': ['house'],
#  'sombre': ['spirits', 'excitement'],
#  'sat': ['down',
#   'down',
#   'alone',
#   'heavy',
#   'on',
#   'down',
#   'she',
#   'dr',
#   'on',
#   'down',
#   'down',
#   'with',
#   'down',
#   'down',
#   'petrified',
#   'under',
#   'beyond',
#   'in',
#   'all',
#   'looking'],
#  'dinner': ['without', 'why', 'when'],
#  'without': ['relish',
#   'further',
#   'bowels',
#   'looking',
#   'any',
#   'doubt',
#   'dropping',
#   'the',
#   'a',
#   'event',
#   'a',
#   'a',
#   'further',
#   'a',
#   'a',
#   'pecuniary',
#   'transition',
#   'efficiency'],
#  'relish': ['it'],
#  'custom': ['of'],
#  'meal': ['was'],
#  'volume': ['of'],
#  'divinity': ['on'],
#  'reading': ['desk', 'of'],
#  'desk': ['until', 'among'],
#  'until': ['the', 'the', 'they', 'they', 'the', 'to-morrow', 'i'],
#  'clock': ['of'],
#  'neighbouring': ['church', 'gutter', 'thoroughfare'],
#  'rang': ['out', 'from'],
#  'hour': ['of',
#   'he',
#   'there',
#   'when',
#   'in',
#   'the',
#   'i',
#   'of',
#   'and',
#   'and',
#   'of',
#   'of',
#   'from',
#   'of'],
#  'twelve': ['when', 'o’clock'],
#  'soberly': ['and'],
#  'gratefully': ['to'],
#  'bed': ['on',
#   'on',
#   'plucked',
#   'about',
#   'and',
#   'and',
#   'is',
#   'i',
#   'with',
#   'curtains',
#   'i',
#   'henry',
#   'i'],
#  'however': ['as',
#   'second',
#   'the',
#   'was',
#   'was',
#   'and',
#   'i',
#   'slightly',
#   'tragic'],
#  'cloth': ['was', 'laying'],
#  'candle': ['and',
#   'put',
#   'drew',
#   'and',
#   'and',
#   'he',
#   'carefully',
#   'to',
#   'was'],
#  'room': ['there',
#   'mr',
#   'in',
#   'would',
#   'in',
#   'poole',
#   'fitted',
#   'was',
#   'and',
#   'digging',
#   'well',
#   'you',
#   'to',
#   'i',
#   'upon',
#   'that',
#   'i',
#   'in',
#   'in',
#   'and',
#   'gnawing',
#   'my'],
#  'opened': ['his', 'the', 'the', 'the', 'till', 'on', 'the', 'one'],
#  'safe': ['took', 'and', 'he', 'mark', 'where', 'it', 'of'],
#  'most': ['private',
#   'part',
#   'honest',
#   'diaphanous',
#   'sedulous',
#   'commonplace',
#   'convenient',
#   'conveniently',
#   'narrow',
#   'plentiful',
#   'naked',
#   'racking',
#   'rigorous',
#   'probable',
#   'studious',
#   'unequally',
#   'sensitive',
#   'capacious',
#   'deadly',
#   'poignant',
#   'strained'],
#  'private': ['part',
#   'matter',
#   'mr',
#   'for',
#   'safe',
#   'cabinet',
#   'manufacture',
#   'room',
#   'room'],
#  'document': ['endorsed', 'had', 'without', 'here', 'he'],
#  'endorsed': ['on'],
#  'envelope': ['as', 'which', 'he', 'addressed', 'was', 'addressed'],
#  'clouded': ['brow'],
#  'brow': ['to', 'like', 'with', 'to'],
#  'study': ['its', 'i', 'a', 'of'],
#  'holograph': ['for'],
#  'charge': ['of'],
#  'now': ['that',
#   'by',
#   'i',
#   'indeed',
#   'his',
#   'i',
#   'said',
#   'for',
#   'plunged',
#   'left',
#   'sat',
#   'my',
#   'lying',
#   'said',
#   'one',
#   'that',
#   'no',
#   'been',
#   'in',
#   'more',
#   'get',
#   'take',
#   'my',
#   'he',
#   'pulled',
#   'wept',
#   'continued',
#   'sir',
#   'begs',
#   'comes',
#   'our',
#   'poole',
#   'quite',
#   'the',
#   'thoroughly',
#   'ten',
#   'to',
#   'four',
#   'for',
#   'faced',
#   'said',
#   'you',
#   'when',
#   'transferred',
#   'two',
#   'i',
#   'the',
#   'saw',
#   'however',
#   'felt',
#   'with',
#   'with',
#   'confined',
#   'my',
#   'i',
#   'condemned',
#   'divided',
#   'seen',
#   'fallen',
#   'fallen',
#   'persuaded',
#   'finishing',
#   'how',
#   'when'],
#  'refused': ['to', 'and'],
#  'lend': ['the'],
#  'assistance': ['in'],
#  'making': ['of', 'a'],
#  'provided': ['not'],
#  'decease': ['of'],
#  'm.d': ['d.c.l'],
#  'd.c.l': ['l.l.d'],
#  'l.l.d': ['f.r.s'],
#  'f.r.s': ['etc'],
#  'etc': ['all'],
#  'possessions': ['were'],
#  'pass': ['into', 'beyond', 'away'],
#  'benefactor': ['edward', 'dr'],
#  'edward': ['hyde',
#   'hyde',
#   'hyde',
#   'hyde',
#   'hyde',
#   'hyde',
#   'hyde',
#   'hyde',
#   'hyde',
#   'hyde',
#   'hyde',
#   'hyde',
#   'hyde',
#   'hyde',
#   'hyde',
#   'hyde',
#   'hyde',
#   'hyde',
#   'hyde',
#   'hyde',
#   'hyde',
#   'hyde',
#   'hyde',
#   'hyde',
#   'hyde'],
#  'disappearance': ['or', 'the', 'of', 'of', 'here', 'and', 'but'],
#  'unexplained': ['absence'],
#  'absence': ['for'],
#  'period': ['exceeding', 'of'],
#  'exceeding': ['three'],
#  'calendar': ['months'],
#  'months': ['the',
#   'since',
#   'the',
#   'to',
#   'before',
#   'before',
#   'however',
#   'i',
#   'of'],
#  'step': ['into', 'or', 'back', 'natural', 'into', 'of', 'leaping'],
#  'shoes': ['without'],
#  'further': ['delay', 'end', 'search', 'parley', 'i'],
#  'delay': ['and', 'but', 'too'],
#  'free': ['from', 'and'],
#  'burthen': ['or', 'of'],
#  'obligation': ['beyond', 'an', 'i'],
#  'beyond': ['the',
#   'this',
#   'me',
#   'the',
#   'that',
#   'redemption',
#   'the',
#   'what',
#   'these'],
#  'payment': ['of'],
#  'sums': ['to'],
#  'members': ['of', 'with'],
#  'household': ['this'],
#  'eyesore': ['it'],
#  'offended': ['him'],
#  'both': ['as',
#   'hands',
#   'at',
#   'thorough',
#   'it’s',
#   'stopped',
#   'pale',
#   'torture',
#   'think',
#   'for',
#   'sides',
#   'sides',
#   'and',
#   'in',
#   'has'],
#  'lover': ['of'],
#  'sane': ['and', 'could'],
#  'customary': ['sides', 'seat'],
#  'sides': ['of', 'of', 'of'],
#  'fanciful': ['was', 'for'],
#  'immodest': ['and'],
#  'hitherto': ['it', 'it', 'unknown', 'accustomed', 'the', 'escaped'],
#  'ignorance': ['of'],
#  'swelled': ['his', 'out'],
#  'indignation': ['now'],
#  'sudden': ['turn',
#   'definite',
#   'reflection',
#   'he',
#   'splutter',
#   'chill',
#   'and'],
#  'knowledge': ['it', 'is', 'and', 'or', 'does'],
#  'learn': ['no', 'the', 'that', 'from'],
#  'clothed': ['upon'],
#  'attributes': ['and'],
#  'shifting': ['insubstantial'],
#  'insubstantial': ['mists'],
#  'mists': ['that'],
#  'baffled': ['his', 'him'],
#  'leaped': ['up', 'against', 'back'],
#  'definite': ['presentment', 'here'],
#  'presentment': ['of'],
#  'fiend': ['i', 'the'],
#  'madness': ['he', 'but'],
#  'replaced': ['the'],
#  'obnoxious': ['paper'],
#  'paper': ['in',
#   'alongside',
#   'and',
#   'telling',
#   'and',
#   'it',
#   'to',
#   'if',
#   'book',
#   'i'],
#  'begin': ['to', 'to', 'after'],
#  'fear': ['it',
#   'was',
#   'with',
#   'he',
#   'i',
#   'death',
#   'as',
#   'founded',
#   'replied',
#   'of',
#   'of',
#   'and',
#   'of',
#   'of'],
#  'disgrace': ['with', 'punishment', 'and'],
#  'blew': ['out'],
#  'greatcoat': ['and', 'but'],
#  'forth': ['in',
#   'from',
#   'utterson',
#   'on',
#   'from',
#   'an',
#   'at',
#   'alone',
#   'in',
#   'it'],
#  'direction': ['of', 'of', 'and', 'only'],
#  'cavendish': ['square', 'square', 'square'],
#  'citadel': ['of'],
#  'medicine': ['where', 'and', 'you', 'wore'],
#  'received': ['his', 'in', 'into', 'a', 'by', 'by', 'by', 'lanyon’s'],
#  'crowding': ['patients'],
#  'patients': ['if'],
#  'anyone': ['knows', 'it'],
#  'knows': ['it', 'what', 'i'],
#  'solemn': ['butler', 'lip'],
#  'butler': ['knew',
#   'indeed',
#   'addressing',
#   'into',
#   'have',
#   'turning',
#   'and',
#   'it',
#   'i',
#   'has',
#   'was'],
#  'welcomed': ['him', 'him'],
#  'subjected': ['to'],
#  'stage': ['of'],
#  'ushered': ['direct'],
#  'direct': ['from'],
#  'dining-room': ['where', 'here', 'one', 'at'],
#  'hearty': ['healthy'],
#  'healthy': ['dapper'],
#  'dapper': ['red-faced'],
#  'red-faced': ['gentleman'],
#  'shock': ['of', 'he'],
#  'hair': ['prematurely', 'drawing', 'stood', 'it'],
#  'prematurely': ['white'],
#  'boisterous': ['and'],
#  'decided': ['manner'],
#  'manner': ['at',
#   'of',
#   'i',
#   'of',
#   'you',
#   'that',
#   'and',
#   'was',
#   'the',
#   'to',
#   'that'],
#  'sprang': ['up', 'up', 'to'],
#  'chair': ['and', 'it', 'or'],
#  'geniality': ['as'],
#  'somewhat': ['theatrical', 'of', 'broken', 'uncertain', 'large', 'odd', 'i'],
#  'theatrical': ['to'],
#  'reposed': ['on', 'from'],
#  'mates': ['both'],
#  'school': ['and', 'companion'],
#  'college': ['both'],
#  'thorough': ['respectors', 'and'],
#  'respectors': ['of'],
#  'themselves': ['and', 'hoarse', 'along', 'made'],
#  'follow': ['men', 'it', 'him', 'others', 'became', 'concerns'],
#  'thoroughly': ['enjoyed', 'examined', 'to'],
#  'other’s': ['company', 'arm'],
#  'company': ['after', 'practising'],
#  'rambling': ['talk'],
#  'disagreeably': ['preoccupied', 'and'],
#  'preoccupied': ['his'],
#  'oldest': ['friends', 'friends'],
#  'wish': ['the', 'you', 'to', 'you', 'to', 'i', 'to'],
#  'younger': ['chuckled', 'lighter', 'than'],
#  'chuckled': ['dr'],
#  'interest': ['we', 'in', 'in', 'in', 'in', 'hyde'],
#  'since': ['henry',
#   'my',
#   'we',
#   'she',
#   'guest',
#   'had',
#   'prepared',
#   'then',
#   'the'],
#  'became': ['too', 'aware', 'once', 'so', 'suddenly', 'lighted', 'in'],
#  'course': ['i',
#   'of',
#   'this',
#   'was',
#   'of',
#   'of',
#   'of',
#   'of',
#   'i',
#   'forgotten'],
#  'continue': ['to', 'as', 'with'],
#  'take': ['an',
#   'in',
#   'a',
#   'you',
#   'a',
#   'a',
#   'a',
#   'your',
#   'him',
#   'the',
#   'your',
#   'a',
#   'this',
#   'stock',
#   'it',
#   'and',
#   'me'],
#  'sake’s': ['sake'],
#  'sake': ['as', 'when', 'i', 'stay', 'he', 'have'],
#  'devilish': ['little', 'fury'],
#  'unscientific': ['balderdash'],
#  'balderdash': ['added'],
#  'flushing': ['suddenly'],
#  'purple': ['would', 'which'],
#  'estranged': ['damon'],
#  ...}

# %% [markdown]
# We can look up any word and find the words that can follow it.

# %%
# I used this cell to find a predecessor with a good number of possible successors
# and at least one repeated word.

def has_duplicates(t):
    return len(set(t)) < len(t)

for key, value in successor_map.items():
    if len(value) == 7 and has_duplicates(value):
        print(key, value)
# Out:
# story ['of', 'of', 'indeed', 'but', 'for', 'of', 'that']
# incident ['of', 'of', 'at', 'of', 'of', 'at', 'this']
# lanyon’s ['narrative', 'there', 'face', 'manner', 'narrative', 'the', 'condemnation']
# common ['it', 'interest', 'friends', 'friends', 'observers', 'but', 'quarry']
# relief ['the', 'to', 'when', 'that', 'that', 'of', 'it']
# appearance ['of', 'well', 'something', 'he', 'amply', 'of', 'which']
# going ['east', 'in', 'to', 'to', 'up', 'to', 'of']
# till ['at', 'the', 'i', 'yesterday', 'the', 'that', 'weariness']
# walk ['and', 'into', 'with', 'all', 'steadfastly', 'attired', 'with']
# sounds ['nothing', 'carried', 'out', 'the', 'of', 'of', 'with']
# really ['like', 'damnable', 'can', 'a', 'a', 'not', 'be']
# does ['not', 'not', 'indeed', 'not', 'the', 'not', 'not']
# reply ['i', 'but', 'whose', 'i', 'some', 'that’s', 'i']
# continued ['mr', 'the', 'the', 'the', 'the', 'poole', 'utterson']
# seems ['scarcely', 'hardly', 'to', 'she', 'much', 'he', 'to']
# walked ['on', 'over', 'some', 'was', 'on', 'with', 'fast']
# that’s ['a', 'it', 'talking', 'very', 'not', 'such', 'not']
# although ['i', 'a', 'it', 'the', 'we', 'they', 'i']
# until ['the', 'the', 'they', 'they', 'the', 'to-morrow', 'i']
# disappearance ['or', 'the', 'of', 'of', 'here', 'and', 'but']
# step ['into', 'or', 'back', 'natural', 'into', 'of', 'leaping']
# wish ['the', 'you', 'to', 'you', 'to', 'i', 'to']
# aware ['of', 'of', 'of', 'that', 'jekyll’s', 'that', 'of']
# thank ['you', 'you', 'you', 'you', 'you', 'god', 'you']
# maid ['servant', 'described', 'fainted', 'had', 'calls', 'had', 'lifted']
# besides ['were', 'was', 'for', 'a', 'with', 'with', 'which']
# observed ['the', 'utterson', 'with', 'the', 'that', 'that', 'that']
# among ['other', 'the', 'the', 'the', 'my', 'my', 'temptations']

# %%
successor_map['going']
# Out:
# ['east', 'in', 'to', 'to', 'up', 'to', 'of']

# %% [markdown]
# In this list of successors, notice that the word `'to'` appears three times -- the other successors only appear once.

# %% [markdown]
# ## Generating text
#
# We can use the results from the previous section to generate new text with the same relationships between consecutive words as in the original.
# Here's how it works:
#
# * Starting with any word that appears in the text, we look up its possible successors and choose one at random.
#
# * Then, using the chosen word, we look up its possible successors, and choose one at random.
#
# We can repeat this process to generate as many words as we want.
# As an example, let's start with the word `'although'`.
# Here are the words that can follow it.

# %%
word = 'although'
successors = successor_map[word]
successors
# Out:
# ['i', 'a', 'it', 'the', 'we', 'they', 'i']

# %%
# this cell initializes the random number generator so it
# starts at the same point in the sequence each time this
# notebook runs.

random.seed(2)

# %% [markdown]
# We can use `choice` to choose from the list with equal probability.

# %%
word = random.choice(successors)
word
# Out:
# 'i'

# %% [markdown]
# If the same word appears more than once in the list, it is more likely to be selected.
#
# Repeating these steps, we can use the following loop to generate a longer series.

# %%
for i in range(10):
    successors = successor_map[word]
    word = random.choice(successors)
    print(word, end=' ')
# Out:
# continue to hesitate and swallowed the smile withered from that

# %% [markdown]
# The result sounds more like a real sentence, but it still doesn't make much sense.
#
# We can do better using more than one word as a key in `successor_map`.
# For example, we can make a dictionary that maps from each bigram -- or trigram -- to the list of words that come next.
# As an exercise, you'll have a chance to implement this analysis and see what the results look like.

# %% [markdown]
# ## Debugging
#
# At this point we are writing more substantial programs, and you might find that you are spending more time debugging.
# If you are stuck on a difficult bug, here are a few things to try:
#
# * Reading: Examine your code, read it back to yourself, and check that it says what you meant to say.
#
# * Running: Experiment by making changes and running different versions. Often if you display the right thing at the right place in the program, the problem becomes obvious, but sometimes you have to build scaffolding.
#
# * Ruminating: Take some time to think! What kind of error is it: syntax, runtime,
#     or semantic? What information can you get from the error messages,
#     or from the output of the program? What kind of error could cause
#     the problem you're seeing? What did you change last, before the
#     problem appeared?
#
# * Rubberducking: If you explain the problem to someone else, you sometimes find the
#     answer before you finish asking the question. Often you don't need
#     the other person; you could just talk to a rubber duck. And that's
#     the origin of the well-known strategy called **rubber duck
#     debugging**. I am not making this up -- see
#     <https://en.wikipedia.org/wiki/Rubber_duck_debugging>.
#
# * Retreating: At some point, the best thing to do is back up -- undoing recent
#     changes -- until you get to a program that works. Then you can start rebuilding.
#
# * Resting: If you give your brain a break, sometime it will find the problem for you.

# %% [markdown]
# Beginning programmers sometimes get stuck on one of these activities and forget the others. Each activity comes with its own failure mode.
#
# For example, reading your code works if the problem is a typographical error, but not if the problem is a conceptual misunderstanding.
# If you don't understand what your program does, you can read it 100 times and never see the error, because the error is in your head.
#
# Running experiments can work, especially if you run small, simple tests.
# But if you run experiments without thinking or reading your code, it can take a long time to figure out what's happening.
#
# You have to take time to think. Debugging is like an experimental science. You should have at least one hypothesis about what the problem is. If there are two or more possibilities, try to think of a test that would eliminate one of them.

# %% [markdown]
# But even the best debugging techniques will fail if there are too many
# errors, or if the code you are trying to fix is too big and complicated.
# Sometimes the best option is to retreat, simplifying the program until
# you get back to something that works.
#
# Beginning programmers are often reluctant to retreat because they can't
# stand to delete a line of code (even if it's wrong). If it makes you
# feel better, copy your program into another file before you start
# stripping it down. Then you can copy the pieces back one at a time.
#
# Finding a hard bug requires reading, running, ruminating, retreating, and sometimes resting.
# If you get stuck on one of these activities, try the others.

# %% [markdown]
# ## Glossary
#
# **default value:**
# The value assigned to a parameter if no argument is provided.
#
# **override:**
#  To replace a default value with an argument.
#
# **deterministic:**
#  A deterministic program does the same thing each time it runs, given the same inputs.
#
# **pseudorandom:**
#  A pseudorandom sequence of numbers appears to be random, but is generated by a deterministic program.
#
# **bigram:**
# A sequence of two elements, often words.
#
# **trigram:**
# A sequence of three elements.
#
# **n-gram:**
# A sequence of an unspecified number of elements.
#
# **rubber duck debugging:**
# A way of debugging by explaining a problem aloud to an inanimate object.

# %% [markdown]
# ## Exercises

# %%
# This cell tells Jupyter to provide detailed debugging information
# when a runtime error occurs. Run it before working on the exercises.

# %xmode Verbose

# %% [markdown]
# ### Ask a virtual assistant
#
# In `add_bigram`, the `if` statement creates a new list or appends an element to an existing list, depending on whether the key is already in the dictionary.

# %%
def add_bigram(bigram):
    first, second = bigram

    if first not in successor_map:
        successor_map[first] = [second]
    else:
        successor_map[first].append(second)

# %% [markdown]
# Dictionaries provide a method called `setdefault` that we can use to do the same thing more concisely.
# Ask a virtual assistant how it works, or copy `add_word` into a virtual assistant and ask "Can you rewrite this using `setdefault`?"
#
# In this chapter we implemented Markov chain text analysis and generation.
# If you are curious, you can ask a virtual assistant for more information on the topic.
# One of the things you might learn is that virtual assistants use algorithms that are similar in many ways -- but also different in important ways.
# Ask a VA, "What are the differences between large language models like GPT and Markov chain text analysis?"

# %% [markdown]
# ### Exercise
#
# Write a function that counts the number of times each trigram (sequence of three words) appears.
# If you test your function with the text of _Dr. Jekyll and Mr. Hyde_, you should find that the most common trigram is "said the lawyer".
#
# Hint: Write a function called `count_trigram` that is similar to `count_bigram`. Then write a function called `process_word_trigram` that is similar to `process_word_bigram`.

# %%
# Solution goes here
trigramcounter={}
def count_trigram(trigram):
    key = tuple(trigram)
    if key not in trigramcounter:
        trigramcounter[key] = 1
    else:
        trigramcounter[key] += 1
window=[]
def process_word_trigram(word):
    window.append(word)
    if len(window) == 3:
        count_trigram(window)
        window.pop(0)

# %%
# Solution goes here
for line in open('pg43.txt'):
    for word in split_line(line):
        word = clean_word(word)
        process_word_trigram(word)

# %% [markdown]
# You can use the following loop to read the book and process the words.

# %%
trigram_counter = {}
window = []

for line in open(filename):
    for word in split_line(line):
        word = clean_word(word)
        process_word_trigram(word)

# %% [markdown]
# ,,www;ll12Then use `print_most_common` to find the most common trigrams in the book.

# %%
print_most_common(trigramcounter)
# Out:
# 20	('said', 'the', 'lawyer')
# 19	('the', 'project', 'gutenberg')
# 18	('project', 'gutenberg™', 'electronic')
# 16	('said', 'mr', 'utterson')
# 15	('of', 'edward', 'hyde')

# %% [markdown]
# ### Exercise
#
# Now let's implement Markov chain text analysis with a mapping from each bigram to a list of possible successors.
#
# Starting with `add_bigram`, write a function called `add_trigram` that takes a list of three words and either adds or updates an item in `successor_map`, using the first two words as the key and the third word as a possible successor.

# %%
# Solution goes here
successor_map={}
def add_trigram(trigram):
    first, second, third = trigram
    key=(first,second)
    if successor_map[key]==[third]:
        successor_map[key].append(third)
    else:
        successor_map[key]=[third]

# %% [markdown]
# Here's a version of `process_word_trigram` that calls `add_trigram`.

# %%
def process_word_trigram(word):
    window.append(word)
    if len(window) == 3:
        add_trigram(window)
        window.pop(0)

# %% [markdown]
# You can use the following loop to test your function with the lyrics of "Eric, the Half a Bee".

# %%
song = """
Half a bee, philosophically,
Must, ipso facto, half not be.
But half the bee has got to be
Vis a vis, its entity. D'you see?
"""

# %%
for string in song.split():
    word = string.strip(punctuation).lower()
    process_word_trigram(word)

# %% [markdown]
# If your function works as intended, the predecessor `('half', 'a')` should map to a list with the single element `'bee'`.
# In fact, as it happens, each bigram in this song appear only once, so all of the values in `successor_map` have a single element.

# %%
successor_map
# Out:
# {}

# %% [markdown]
# You can use the following loop to test your function with the words from the book.

# %%
successor_map = {}
window = []

for line in open(filename):
    for word in split_line(line):
        word = clean_word(word)
        process_word_trigram(word)

# %% [markdown]
# In the next exercise, you'll use the results to generate new random text.

# %% [markdown]
# ### Exercise
#
# For this exercise, we'll assume that `successor_map` is a dictionary that maps from each bigram to the list of words that follow it.

# %%
# this cell initializes the random number generator so it
# starts at the same point in the sequence each time this
# notebook runs.

random.seed(3)

# %% [markdown]
# To generate random text, we'll start by choosing a random key from `successor_map`.

# %%
successors = list(successor_map)
bigram = random.choice(successors)
bigram

# %% [markdown]
# Now write a loop that generates 50 more words following these steps:
#
# 1. In `successor_map`, look up the list of words that can follow `bigram`.
#
# 2. Choose one of them at random and print it.
#
# 3. For the next iteration, make a new bigram that contains the second word from `bigram` and the chosen successor.
#
# For example, if we start with the bigram `('doubted', 'if')` and choose `'from'` as its successor, the next bigram is `('if', 'from')`.

# %%
# Solution goes here

# %% [markdown]
# If everything is working, you should find that the generated text is recognizably similar in style to the original, and some phrases make sense, but the text might wander from one topic to another.
#
# As a bonus exercise, modify your solution to the last two exercises to use trigrams as keys in `successor_map`, and see what effect it has on the results.

# %% [markdown]
# [Think Python: 3rd Edition](https://allendowney.github.io/ThinkPython/index.html)
#
# Copyright 2024 [Allen B. Downey](https://allendowney.com)
#
# Code license: [MIT License](https://mit-license.org/)
#
# Text license: [Creative Commons Attribution-NonCommercial-ShareAlike 4.0 International](https://creativecommons.org/licenses/by-nc-sa/4.0/)
